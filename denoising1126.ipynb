# %%
"""
This is the version of compute frequency error, PSNR, SSIM, and loss of different other_optimizers
by Chaoyan Nov. 26th, 2025
*Uncomment if running on colab*
Set Runtime -> Change runtime type -> Under Hardware Accelerator select GPU in Google Colab
"""
#!git clone https://github.com/DmitryUlyanov/deep-image-prior
#!mv deep-image-prior/* ./
# Out:
# '\n*Uncomment if running on colab*\nSet Runtime -> Change runtime type -> Under Hardware Accelerator select GPU in Google Colab\n'

# %% [markdown]
# # Import libs

# %%
from __future__ import print_function
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
from models import *

import random
import torch
import torch.optim

from skimage.metrics import peak_signal_noise_ratio as compare_psnr
from skimage.metrics import structural_similarity as compare_ssim

from utils.denoising_utils import *



torch.backends.cudnn.enabled = True
torch.backends.cudnn.benchmark =True
dtype = torch.cuda.FloatTensor

imsize =-1
PLOT = True
sigma = 25
sigma_ = sigma/255.
torch.manual_seed(2025) # Fixed random seed for reproducibility

# %%
# deJPEG
# fname = 'data/denoising/snail.jpg'

## denoising
fname = 'data/denoising/F16_GT.png'

# %% [markdown]
# # Load image

# %%
if fname == 'data/denoising/snail.jpg':
    img_noisy_pil = crop_image(get_image(fname, imsize)[0], d=32)
    img_noisy_np = pil_to_np(img_noisy_pil)

    # As we don't have ground truth
    img_pil = img_noisy_pil
    img_np = img_noisy_np

    if PLOT:
        plot_image_grid([img_np], 4, 5);

elif fname == 'data/denoising/F16_GT.png':
    # Add synthetic noise
    img_pil = crop_image(get_image(fname, imsize)[0], d=32)
    img_np = pil_to_np(img_pil)

    img_noisy_pil, img_noisy_np = get_noisy_image(img_np, sigma_)

    if PLOT:
        plot_image_grid([img_np, img_noisy_np], 4, 6);
else:
    assert False

# %% [markdown]
# # Setup

# %%
INPUT = 'noise' # 'meshgrid'
pad = 'reflection'
OPT_OVER = 'net' # 'net,input'

reg_noise_std = 1./30. # set to 1./20. for sigma=

LR = 0.02 # ADAM

show_every = 1
exp_weight=0.99

if fname == 'data/denoising/snail.jpg':
    num_iter = 2400
    input_depth = 3
    figsize = 5

    net = skip(
                input_depth, 3,
                num_channels_down = [8, 16, 32, 64, 128],
                num_channels_up   = [8, 16, 32, 64, 128],
                num_channels_skip = [0, 0, 0, 4, 4],
                upsample_mode='bilinear',
                need_sigmoid=True, need_bias=True, pad=pad, act_fun='LeakyReLU')

    net = net.type(dtype)

elif fname == 'data/denoising/F16_GT.png':
    num_iter = 3000
    input_depth = 32
    figsize = 4


    net = get_net(input_depth, 'skip', pad,
                  skip_n33d=128,
                  skip_n33u=128,
                  skip_n11=4,
                  num_scales=5,
                  upsample_mode='bilinear').type(dtype)

else:
    assert False

net_input = get_noise(input_depth, INPUT, (img_pil.size[1], img_pil.size[0])).type(dtype).detach()

# Compute number of parameters
s  = sum([np.prod(list(p.size())) for p in net.parameters()]);
print ('Number of params: %d' % s)

# Loss
mse = torch.nn.MSELoss().type(dtype)

img_noisy_torch = np_to_torch(img_noisy_np).type(dtype)
# Out:
# Number of params: 2217831

# %%
# from transformers import Adafactor
def optimize(optimizer_type, parameters, closure, LR, num_iter):
    if optimizer_type == 'LBFGS':
        print('Starting optimization with LBFGS')
        def closure2():
            optimizer.zero_grad()
            return closure()
        optimizer = torch.optim.LBFGS(parameters, max_iter=num_iter, lr=LR, tolerance_grad=-1, tolerance_change=-1)
        optimizer.step(closure2)

    else:
        opt_class = {
            'adam': torch.optim.Adam,
            'SGD': torch.optim.SGD,
            'RMSprop': torch.optim.RMSprop,
            'AdamW': torch.optim.AdamW,
            'RAdam': torch.optim.RAdam,
            # 'Adafactor': Adafactor #torch.optim.Adafactor
            'ASGD': torch.optim.ASGD
        }[optimizer_type]
        optimizer = opt_class(parameters, lr=LR)
        print(f'Starting optimization with {optimizer_type.upper()}')
        for j in range(num_iter):
            optimizer.zero_grad()
            loss = closure()
            optimizer.step()

# %%
# index measurements

from unittest import result


def l1_l2_ratio_model(model):
    '''
    Param Bias=|\theta|1/|\theta|_2
    大 L1/L2 比值 → 参数更“分散”，偏向稀疏解
    小 L1/L2 → 参数接近均匀分布，偏向小范数解
    '''
    all_params = torch.cat([p.detach().view(-1) for p in model.parameters()])
    l1 = torch.sum(all_params.abs())
    l2 = torch.norm(all_params, p=2)
    return (l1 / (l2 + 1e-12)).item()



def frequency_bias(x):
    """
    Compute Freq Bias=log(1+∣F(fθ​(x))∣), return a scalar float.
    卷积结构天然偏向低频 → log(1+|Fx|) 高，反映网络先拟合平滑部分
    """
    # FFT: shape [B, C, H, W], complex
    Xf = torch.fft.fft2(x, norm='ortho')

    # magnitude
    Xf_mag = torch.abs(Xf)

    # log(1 + |F(x)|)
    log_fx = torch.log1p(Xf_mag)

    # return single scalar (mean over all entries)
    return log_fx.mean().item()

def frequency_bias_diff(x1,x2):
    Xf1 = torch.fft.fft2(x1, norm='ortho')
    Xf2 = torch.fft.fft2(x2, norm='ortho')
    Xf_mag1 = torch.abs(Xf1)
    Xf_mag2 = torch.abs(Xf2)
    log_fx1 = torch.log1p(Xf_mag1)
    log_fx2 = torch.log1p(Xf_mag2)
    diff = log_fx1 - log_fx2
    num_up = torch.norm(diff, p=2).item()
    num_down = np.minimum(torch.norm(log_fx1, p=2).item(),torch.norm(log_fx2, p=2).item())
    result = num_up / num_down
    return result

def frequency_bias_diff_wolog(x1,x2):
    Xf1 = torch.fft.fft2(x1, norm='ortho')
    Xf2 = torch.fft.fft2(x2, norm='ortho')
    Xf_mag1 = torch.abs(Xf1)
    Xf_mag2 = torch.abs(Xf2)
    log_fx1 = Xf_mag1 #torch.log1p(Xf_mag1)
    log_fx2 = Xf_mag2 #torch.log1p(Xf_mag2)
    diff = log_fx1 - log_fx2
    num_up = torch.norm(diff, p=2).item()
    num_down = np.minimum(torch.norm(log_fx1, p=2).item(),torch.norm(log_fx2, p=2).item())
    result = num_up / num_down
    return result

def sensitivity_bias(model, x, num_samples=1):
    """
    Sensitivity / Random Trace/ Random Trace / Jacobian Norm
    Tr(J_x J_X^T)
    E[ || J(x)^T ξ ||^2 ], where ξ ~ N(0, I), same shape as model(x)
    函数输出对输入扰动的敏感程度
    大值 → 输出容易随输入变化 → 函数不平滑
    小值 → 输出平滑，对小扰动不敏感 → 强隐式正则, 说明网络天然正则化
    """
    sensitivity = 0.0
    x = x.clone().detach().requires_grad_(True)
    y = model(x)

    for _ in range(num_samples):
        # ξ MUST have same shape as y
        xi = torch.randn_like(y)
        # compute J^T xi wrt input x
        Jv = torch.autograd.grad(
            outputs=y,
            inputs=x,
            grad_outputs=xi,
            retain_graph=True,
            create_graph=False,
        )[0]
        sensitivity += (Jv.pow(2).sum()).item()

    return sensitivity / num_samples

def jacobian_fro_norm(model, x, max_outputs=256):
    """
    Compute the Frobenius norm of the Jacobian J_x f(x):
        ||J||_F^2 = sum_{i,j} (∂y_i / ∂x_j)^2

    model: neural network f
    x: input tensor with requires_grad=True
    max_outputs: we limit how many output dimensions to avoid explosion
    """

    # Clone input with grad
    x = x.clone().detach().requires_grad_(True)
    y = model(x)
    y_flat = y.view(-1)  # flatten output

    # To reduce computation cost, use only first k outputs
    K = min(max_outputs, y_flat.shape[0])
    fro_sq = 0.0

    for i in range(K):
        grad_i = torch.autograd.grad(
            y_flat[i], x,
            retain_graph=True,
            create_graph=False
        )[0]  # same shape as x

        fro_sq += grad_i.pow(2).sum().item()

    return fro_sq


def jacobian_metrics(model, x, num_trace_samples=1, max_fro_outputs=256):
    """
    Compute both:
        1. Sensitivity Bias (Hutchinson Trace Estimation)
            Tr(JJ^T) ≈ E[ || J^T ξ ||^2 ]
        2. Jacobian Frobenius Norm (partial)
            ||J||_F^2 = sum_{i,j} (∂y_i/∂x_j)^2

    Args:
        model: neural network
        x: input tensor
        num_trace_samples: number of Hutchinson samples
        max_fro_outputs: limit # of outputs to compute Frobenius norm

    Returns:
        sensitivity_trace: float
        frobenius_norm: float
    """

    # Prepare input
    x = x.clone().detach().requires_grad_(True)
    y = model(x)
    y_flat = y.view(-1)

    # ----- 1) Sensitivity (Hutchinson Trace) -----
    sensitivity_trace = 0.0
    for _ in range(num_trace_samples):
        xi = torch.randn_like(y)  # same shape as output
        Jv = torch.autograd.grad(
            outputs=y,
            inputs=x,
            grad_outputs=xi,
            retain_graph=True,
            create_graph=False,
        )[0]
        sensitivity_trace += Jv.pow(2).sum().item()
    sensitivity_trace /= num_trace_samples

    # ----- 2) Frobenius Norm (partial) -----
    fro_sq = 0.0
    K = min(max_fro_outputs, y_flat.shape[0])
    for i in range(K):
        grad_i = torch.autograd.grad(
            outputs=y_flat[i],
            inputs=x,
            retain_graph=True,
            create_graph=False,
        )[0]
        fro_sq += grad_i.pow(2).sum().item()

    return sensitivity_trace, fro_sq



def ntk_spectrum(model, x, n_eig=20):
    """
    Compute top NTK eigenvalues using Jacobian-vector product.
    x: input batch (B,C,H,W)
    大的最大特征值 → 网络对输入变化敏感（容易拟合高频）
    小的最大特征值 → 网络较平滑（偏向低频映射）
    """
    model.eval()
    x = x.requires_grad_(True)
    y = model(x)                     # (B, C, H, W)
    B = y.shape[0]
    # Flatten output per sample
    y = y.view(B, -1)
    # Compute Jv for random v
    eigvals = []
    for _ in range(n_eig):
        v = torch.randn_like(y)
        Jv = torch.autograd.grad(
            outputs=y,
            inputs=list(model.parameters()),
            grad_outputs=v,
            retain_graph=True,
            create_graph=False,
            allow_unused=True
        )

        # Convert (list of tensors) → one big vector
        Jv_flat = torch.cat([g.reshape(-1) for g in Jv if g is not None])

        eigvals.append(Jv_flat.pow(2).sum().item())

    return {"NTK_eigenvalues": sorted(eigvals, reverse=True)}

def measure_biases(model, x, img_out):
    return {
        "param_bias": param_bias(model),
        "ntk": ntk_spectrum(model, x),
        "frequency_bias": frequency_bias(img_out),
        "sensitivity": sensitivity_bias(model, x)
    }
FREQ_PARAM = 1000        # every step
FREQ_FREQ_BIAS = 1000    # every 5 steps
FREQ_SENS = 1000        # every 20 steps
FREQ_NTK = 1000        # every 100 steps

# %% [markdown]
# # Optimize

# %%
import torch
import matplotlib.pyplot as plt
from skimage.metrics import peak_signal_noise_ratio as compare_psnr
import numpy as np
import copy

# Define the list of optimizers to run
OPTIMIZER_LIST = ['SGD', 'LBFGS', 'adam', 'ASGD', 'AdamW', 'RAdam'] #['SGD', 'LBFGS', 'adam']#

# Define a dictionary for learning rates for each optimizer
OPTIMIZER_LRS = {
    'SGD': 3,
    'ASGD':3,
    'LBFGS': 2, #2.5 worse
    'adam': 0.001,
    'RMSprop': 0.01,
    'AdamW': 0.005,
    'RAdam': 0.05, # 1.5
    'Adafactor': 0.05
}

results = {}

def run_optimizer(OPTIMIZER_name, current_LR):
    print(f"\n===== Running {OPTIMIZER_name.upper()} with LR={current_LR} for {num_iter} iterations =====")

    # === 重新初始化网络与输入 ===
    net = get_net(input_depth, 'skip', pad,
                  skip_n33d=128,
                  skip_n33u=128,
                  skip_n11=4,
                  num_scales=5,
                  upsample_mode='bilinear').type(dtype)

    net_input = get_noise(input_depth, INPUT, (img_pil.size[1], img_pil.size[0])).type(dtype).detach()
    net_input_saved = net_input.detach().clone()
    noise = net_input.detach().clone()

    out_avg = None
    last_net = None
    psrn_noisy_last = 0

    loss_values = []
    psnr_values = []
    psnr_sm_values = []

    metrics_l1_l2 = []
    metric_freq = []
    metric_sens = []
    metric_jf = []
    metric_sens_jf = []
    metric_ntk = []
    finalresult = []
    finalresultsm = []


    i = 0 # This counter is reset for each optimizer run
    def closure():
        nonlocal i, out_avg, psrn_noisy_last, last_net, net_input

        if reg_noise_std > 0:
            net_input = net_input_saved + (noise.normal_() * reg_noise_std)

        out = net(net_input)

        finalresult.append(out.detach())

        # Smoothing
        if out_avg is None:
            out_avg = out.detach()
        else:
            out_avg = out_avg * exp_weight + out.detach() * (1 - exp_weight)

        # finalresultsm.append(out_avg.detach())

        total_loss = mse(out, img_noisy_torch)
        total_loss.backward()
        loss_values.append(total_loss.item())

        psrn_gt = compare_psnr(img_np, out.detach().cpu().numpy()[0])
        psrn_gt_sm = compare_psnr(img_np, out_avg.detach().cpu().numpy()[0])
        psnr_values.append(psrn_gt)
        psnr_sm_values.append(psrn_gt_sm)

        # ======================================================
        # if i % FREQ_PARAM == 0:
            # ratio = l1_l2_ratio_model(net)
            # metrics_l1_l2.append((ratio))
            # print(f"L1/L2={ratio:.5f}")
        # else:
            # metrics_l1_l2.append(ratio[-1])

        # Frequency bias every few steps
        # if i % FREQ_FREQ_BIAS == 0:
        #     freq_val = frequency_bias(out.detach())
        #     metric_freq.append(freq_val)
        #     print(f"log(1+|Fx|)={freq_val:.5f}")
        # else:
        #     metric_freq.append(metric_freq[-1] if len(metric_freq) > 0 else 0)

        # sensitivity
        # if i % FREQ_SENS == 0:
            # sens_val = sensitivity_bias(net, net_input_saved)
            # metric_sens.append(sens_val)
            # print(f"Random Trace={sens_val:.5f}")
            # jf_val = jacobian_fro_norm(net, net_input_saved)
            # metric_jf.append(jf_val)
            # print(f"Frobenius Norm={jf_val:.5f}")
            # sens_val, fro_val = jacobian_metrics(net, net_input_saved)
            # metric_sens.append(sens_val)
            # metric_jf.append(fro_val)
            # metric_sens_jf.append((sens_val/fro_val))
            # print(f"Random Trace={sens_val:.5f}")
            # print(f"Frobenius Norm={fro_val:.5f}")
        # else:
            # metric_sens.append(metric_sens[-1] if len(metric_sens) > 0 else 0)

        # NTK spectrum: only store largest eigenvalue
        # if i % FREQ_NTK == 0:
            # nk = ntk_spectrum(net, net_input_saved, n_eig=1)
            # metric_ntk.append(nk)
            # net_copy = copy.deepcopy(net)
            # x_copy = net_input_saved.clone().detach().requires_grad_(True)
            # nk = ntk_spectrum(net_copy, x_copy, n_eig=20)
            # metric_ntk.append(nk)

            # print(f"NTK={nk}")
        # else:
            # metric_ntk.append(metric_ntk[-1] if len(metric_ntk) > 0 else 0)

        # Print iteration count as 1-based for user clarity
        print(f"[{OPTIMIZER_name}] Iter {i+1:05d}/{num_iter:05d} | Loss {total_loss.item():.6f} | PSNR_gt {psrn_gt:.2f} | PSNR_gt_sm {psrn_gt_sm:.2f}") # | L1/L2 {ratio:.5f}")
        i += 1
        return total_loss

    p = get_params(OPT_OVER, net, net_input)
    optimize(OPTIMIZER_name, p, closure, current_LR, num_iter) # Use current_LR here

    return {
        'loss': loss_values,
        'psnr': psnr_values,
        'psnr_sm': psnr_sm_values,
        'ratio': metrics_l1_l2,
        'freq': metric_freq,
        'sens': metric_sens,
        'jf': metric_jf,
        'sens_jf': metric_sens_jf,
        'ntk': metric_ntk,
        'finalresult': finalresult,
        'finalresultsm': finalresultsm
    }


# ========== main loop for every optimizer ========== # Iterate using OPTIMIZER_LIST and OPTIMIZER_LRS
for OPTIMIZER_name in OPTIMIZER_LIST:
    # fix random input
    torch.manual_seed(2025)
    np.random.seed(2025)
    random.seed(2025)
    lr_for_optimizer = OPTIMIZER_LRS.get(OPTIMIZER_name, LR) # Get LR from dict, fallback to global LR
    results[OPTIMIZER_name] = run_optimizer(OPTIMIZER_name, lr_for_optimizer)


# ========== plot ========== # Plotting logic remains the same, as it depends on the 'results' dictionary.
plt.figure(figsize=(18, 5))

# ---- (1) Loss ----
plt.subplot(1, 3, 1)
for opt_name, data in results.items():
    plt.plot(data['loss'], label=f'{opt_name} (LR={OPTIMIZER_LRS.get(opt_name, LR)})')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()
plt.grid(True)

# ---- (2) PSNR (GT) ----
plt.subplot(1, 3, 2)
for opt_name, data in results.items():
    plt.plot(data['psnr'], label=f'{opt_name} (LR={OPTIMIZER_LRS.get(opt_name, LR)})')
plt.xlabel('Iteration')
plt.ylabel('PSNR')
plt.title('PSNR (GT)')
plt.legend()
plt.grid(True)

# ---- (3) PSNR (Smoothed) ----
plt.subplot(1, 3, 3)
for opt_name, data in results.items():
    plt.plot(data['psnr_sm'], label=f'{opt_name} (LR={OPTIMIZER_LRS.get(opt_name, LR)})')
plt.xlabel('Iteration')
plt.ylabel('PSNR')
plt.title('PSNR (Smoothed)')
plt.legend()
plt.grid(True)

plt.suptitle('Image Denoising Results under Different Optimizers (Each from Scratch)', fontsize=16, fontweight='bold')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()


iters = np.arange(num_iter)

def plot_metric(metric_name):
    plt.figure(figsize=(10,5))
    for opt_name in results:
        if metric_name == 'ntk':
          plt.subplot(1, 3, 1)
          ntk_vals = [d['NTK_eigenvalues'][0] for d in results[opt_name]['ntk']]
          plt.plot(ntk_vals, label=opt_name)
          plt.title([metric_name, 'eigenvalues 1'])
          plt.xlabel("Iteration")
          plt.grid(True)
          plt.legend()
          plt.subplot(1, 3, 2)
          ntk_vals1_5 = [d['NTK_eigenvalues'][0]/d['NTK_eigenvalues'][4] for d in results[opt_name]['ntk']]
          plt.plot(ntk_vals1_5, label=opt_name)
          plt.title([metric_name, 'eigenvalues 1/5'])
          plt.xlabel("Iteration")
          plt.grid(True)
          plt.legend()
          plt.subplot(1, 3, 3)
          ntk_vals1_20 = [d['NTK_eigenvalues'][0]/d['NTK_eigenvalues'][19] for d in results[opt_name]['ntk']]
          plt.plot(ntk_vals1_20, label=opt_name)
          plt.title([metric_name, 'eigenvalues 1/20'])
          plt.xlabel("Iteration")
          plt.grid(True)
          plt.legend()
        else:
          plt.plot(results[opt_name][metric_name], label=opt_name)
          plt.title(metric_name)
    plt.xlabel("Iteration")
    plt.grid(True)
    plt.legend()
    plt.show()

# plot_metric('ratio')
# plot_metric('freq')
# plot_metric('sens')
# plot_metric('jf')
# plot_metric('sens_jf')
# plot_metric('ntk')
# Out:
# ===== Running SGD with LR=3 for 3000 iterations =====
# Starting optimization with SGD
# [SGD] Iter 00001/03000 | Loss 0.089692 | PSNR_gt 10.91 | PSNR_gt_sm 10.91
# [SGD] Iter 00002/03000 | Loss 0.049540 | PSNR_gt 13.91 | PSNR_gt_sm 10.98
# [SGD] Iter 00003/03000 | Loss 0.062909 | PSNR_gt 12.67 | PSNR_gt_sm 11.03
# [SGD] Iter 00004/03000 | Loss 0.051424 | PSNR_gt 13.70 | PSNR_gt_sm 11.09
# [SGD] Iter 00005/03000 | Loss 0.053481 | PSNR_gt 13.49 | PSNR_gt_sm 11.14
# [SGD] Iter 00006/03000 | Loss 0.045074 | PSNR_gt 14.41 | PSNR_gt_sm 11.19
# [SGD] Iter 00007/03000 | Loss 0.039355 | PSNR_gt 15.16 | PSNR_gt_sm 11.25
# [SGD] Iter 00008/03000 | Loss 0.034404 | PSNR_gt 15.94 | PSNR_gt_sm 11.31
# [SGD] Iter 00009/03000 | Loss 0.031267 | PSNR_gt 16.51 | PSNR_gt_sm 11.37
# [SGD] Iter 00010/03000 | Loss 0.029646 | PSNR_gt 16.85 | PSNR_gt_sm 11.44
# [SGD] Iter 00011/03000 | Loss 0.028717 | PSNR_gt 17.04 | PSNR_gt_sm 11.50
# [SGD] Iter 00012/03000 | Loss 0.026886 | PSNR_gt 17.47 | PSNR_gt_sm 11.57
# [SGD] Iter 00013/03000 | Loss 0.026629 | PSNR_gt 17.53 | PSNR_gt_sm 11.63
# [SGD] Iter 00014/03000 | Loss 0.025720 | PSNR_gt 17.76 | PSNR_gt_sm 11.70
# [SGD] Iter 00015/03000 | Loss 0.025076 | PSNR_gt 17.93 | PSNR_gt_sm 11.76
# [SGD] Iter 00016/03000 | Loss 0.025207 | PSNR_gt 17.90 | PSNR_gt_sm 11.83
# [SGD] Iter 00017/03000 | Loss 0.024658 | PSNR_gt 18.05 | PSNR_gt_sm 11.90
# [SGD] Iter 00018/03000 | Loss 0.025189 | PSNR_gt 17.91 | PSNR_gt_sm 11.96
# [SGD] Iter 00019/03000 | Loss 0.025879 | PSNR_gt 17.72 | PSNR_gt_sm 12.03
# [SGD] Iter 00020/03000 | Loss 0.025866 | PSNR_gt 17.73 | PSNR_gt_sm 12.10
# [SGD] Iter 00021/03000 | Loss 0.025487 | PSNR_gt 17.82 | PSNR_gt_sm 12.16
# [SGD] Iter 00022/03000 | Loss 0.024565 | PSNR_gt 18.07 | PSNR_gt_sm 12.22
# [SGD] Iter 00023/03000 | Loss 0.023735 | PSNR_gt 18.33 | PSNR_gt_sm 12.29
# [SGD] Iter 00024/03000 | Loss 0.023242 | PSNR_gt 18.46 | PSNR_gt_sm 12.36
# [SGD] Iter 00025/03000 | Loss 0.023122 | PSNR_gt 18.52 | PSNR_gt_sm 12.43
# [SGD] Iter 00026/03000 | Loss 0.022505 | PSNR_gt 18.70 | PSNR_gt_sm 12.49
# [SGD] Iter 00027/03000 | Loss 0.021791 | PSNR_gt 18.95 | PSNR_gt_sm 12.56
# [SGD] Iter 00028/03000 | Loss 0.021737 | PSNR_gt 18.95 | PSNR_gt_sm 12.63
# [SGD] Iter 00029/03000 | Loss 0.022380 | PSNR_gt 18.76 | PSNR_gt_sm 12.69
# [SGD] Iter 00030/03000 | Loss 0.022301 | PSNR_gt 18.76 | PSNR_gt_sm 12.76
# [SGD] Iter 00031/03000 | Loss 0.022280 | PSNR_gt 18.78 | PSNR_gt_sm 12.83
# [SGD] Iter 00032/03000 | Loss 0.021481 | PSNR_gt 19.04 | PSNR_gt_sm 12.89
# [SGD] Iter 00033/03000 | Loss 0.021465 | PSNR_gt 19.06 | PSNR_gt_sm 12.96
# [SGD] Iter 00034/03000 | Loss 0.021330 | PSNR_gt 19.10 | PSNR_gt_sm 13.02
# [SGD] Iter 00035/03000 | Loss 0.021636 | PSNR_gt 18.99 | PSNR_gt_sm 13.09
# [SGD] Iter 00036/03000 | Loss 0.021240 | PSNR_gt 19.13 | PSNR_gt_sm 13.15
# [SGD] Iter 00037/03000 | Loss 0.020925 | PSNR_gt 19.24 | PSNR_gt_sm 13.22
# [SGD] Iter 00038/03000 | Loss 0.021283 | PSNR_gt 19.12 | PSNR_gt_sm 13.29
# [SGD] Iter 00039/03000 | Loss 0.020945 | PSNR_gt 19.24 | PSNR_gt_sm 13.35
# [SGD] Iter 00040/03000 | Loss 0.020513 | PSNR_gt 19.40 | PSNR_gt_sm 13.42
# [SGD] Iter 00041/03000 | Loss 0.020388 | PSNR_gt 19.45 | PSNR_gt_sm 13.48
# [SGD] Iter 00042/03000 | Loss 0.020384 | PSNR_gt 19.45 | PSNR_gt_sm 13.55
# [SGD] Iter 00043/03000 | Loss 0.019978 | PSNR_gt 19.61 | PSNR_gt_sm 13.61
# [SGD] Iter 00044/03000 | Loss 0.019954 | PSNR_gt 19.62 | PSNR_gt_sm 13.68
# [SGD] Iter 00045/03000 | Loss 0.019835 | PSNR_gt 19.67 | PSNR_gt_sm 13.75
# [SGD] Iter 00046/03000 | Loss 0.019750 | PSNR_gt 19.71 | PSNR_gt_sm 13.81
# [SGD] Iter 00047/03000 | Loss 0.019268 | PSNR_gt 19.90 | PSNR_gt_sm 13.88
# [SGD] Iter 00048/03000 | Loss 0.019652 | PSNR_gt 19.74 | PSNR_gt_sm 13.94
# [SGD] Iter 00049/03000 | Loss 0.019399 | PSNR_gt 19.85 | PSNR_gt_sm 14.00
# [SGD] Iter 00050/03000 | Loss 0.019682 | PSNR_gt 19.74 | PSNR_gt_sm 14.07
# [SGD] Iter 00051/03000 | Loss 0.019546 | PSNR_gt 19.79 | PSNR_gt_sm 14.13
# [SGD] Iter 00052/03000 | Loss 0.019718 | PSNR_gt 19.71 | PSNR_gt_sm 14.20
# [SGD] Iter 00053/03000 | Loss 0.019480 | PSNR_gt 19.82 | PSNR_gt_sm 14.26
# [SGD] Iter 00054/03000 | Loss 0.019616 | PSNR_gt 19.76 | PSNR_gt_sm 14.32
# [SGD] Iter 00055/03000 | Loss 0.019673 | PSNR_gt 19.75 | PSNR_gt_sm 14.39
# [SGD] Iter 00056/03000 | Loss 0.019462 | PSNR_gt 19.82 | PSNR_gt_sm 14.45
# [SGD] Iter 00057/03000 | Loss 0.019497 | PSNR_gt 19.81 | PSNR_gt_sm 14.51
# [SGD] Iter 00058/03000 | Loss 0.019536 | PSNR_gt 19.79 | PSNR_gt_sm 14.57
# [SGD] Iter 00059/03000 | Loss 0.019495 | PSNR_gt 19.81 | PSNR_gt_sm 14.64
# [SGD] Iter 00060/03000 | Loss 0.019390 | PSNR_gt 19.85 | PSNR_gt_sm 14.70
# [SGD] Iter 00061/03000 | Loss 0.019449 | PSNR_gt 19.83 | PSNR_gt_sm 14.76
# [SGD] Iter 00062/03000 | Loss 0.019315 | PSNR_gt 19.88 | PSNR_gt_sm 14.82
# [SGD] Iter 00063/03000 | Loss 0.019263 | PSNR_gt 19.91 | PSNR_gt_sm 14.88
# [SGD] Iter 00064/03000 | Loss 0.019118 | PSNR_gt 19.97 | PSNR_gt_sm 14.94
# [SGD] Iter 00065/03000 | Loss 0.018731 | PSNR_gt 20.14 | PSNR_gt_sm 15.00
# [SGD] Iter 00066/03000 | Loss 0.018866 | PSNR_gt 20.08 | PSNR_gt_sm 15.06
# [SGD] Iter 00067/03000 | Loss 0.019395 | PSNR_gt 19.85 | PSNR_gt_sm 15.12
# [SGD] Iter 00068/03000 | Loss 0.019507 | PSNR_gt 19.80 | PSNR_gt_sm 15.18
# [SGD] Iter 00069/03000 | Loss 0.019459 | PSNR_gt 19.83 | PSNR_gt_sm 15.24
# [SGD] Iter 00070/03000 | Loss 0.019201 | PSNR_gt 19.93 | PSNR_gt_sm 15.30
# [SGD] Iter 00071/03000 | Loss 0.018761 | PSNR_gt 20.12 | PSNR_gt_sm 15.36
# [SGD] Iter 00072/03000 | Loss 0.018207 | PSNR_gt 20.39 | PSNR_gt_sm 15.42
# [SGD] Iter 00073/03000 | Loss 0.018284 | PSNR_gt 20.35 | PSNR_gt_sm 15.47
# [SGD] Iter 00074/03000 | Loss 0.018530 | PSNR_gt 20.24 | PSNR_gt_sm 15.54
# [SGD] Iter 00075/03000 | Loss 0.018235 | PSNR_gt 20.37 | PSNR_gt_sm 15.59
# [SGD] Iter 00076/03000 | Loss 0.018304 | PSNR_gt 20.34 | PSNR_gt_sm 15.65
# [SGD] Iter 00077/03000 | Loss 0.018115 | PSNR_gt 20.43 | PSNR_gt_sm 15.71
# [SGD] Iter 00078/03000 | Loss 0.018239 | PSNR_gt 20.37 | PSNR_gt_sm 15.77
# [SGD] Iter 00079/03000 | Loss 0.018468 | PSNR_gt 20.26 | PSNR_gt_sm 15.82
# [SGD] Iter 00080/03000 | Loss 0.018277 | PSNR_gt 20.35 | PSNR_gt_sm 15.88
# [SGD] Iter 00081/03000 | Loss 0.018278 | PSNR_gt 20.35 | PSNR_gt_sm 15.94
# [SGD] Iter 00082/03000 | Loss 0.018464 | PSNR_gt 20.26 | PSNR_gt_sm 15.99
# [SGD] Iter 00083/03000 | Loss 0.018317 | PSNR_gt 20.32 | PSNR_gt_sm 16.05
# [SGD] Iter 00084/03000 | Loss 0.017855 | PSNR_gt 20.56 | PSNR_gt_sm 16.11
# [SGD] Iter 00085/03000 | Loss 0.018019 | PSNR_gt 20.47 | PSNR_gt_sm 16.16
# [SGD] Iter 00086/03000 | Loss 0.017990 | PSNR_gt 20.49 | PSNR_gt_sm 16.22
# [SGD] Iter 00087/03000 | Loss 0.017700 | PSNR_gt 20.63 | PSNR_gt_sm 16.27
# [SGD] Iter 00088/03000 | Loss 0.017628 | PSNR_gt 20.67 | PSNR_gt_sm 16.33
# [SGD] Iter 00089/03000 | Loss 0.017655 | PSNR_gt 20.65 | PSNR_gt_sm 16.38
# [SGD] Iter 00090/03000 | Loss 0.017701 | PSNR_gt 20.63 | PSNR_gt_sm 16.44
# [SGD] Iter 00091/03000 | Loss 0.018317 | PSNR_gt 20.33 | PSNR_gt_sm 16.49
# [SGD] Iter 00092/03000 | Loss 0.018326 | PSNR_gt 20.32 | PSNR_gt_sm 16.55
# [SGD] Iter 00093/03000 | Loss 0.017850 | PSNR_gt 20.55 | PSNR_gt_sm 16.60
# [SGD] Iter 00094/03000 | Loss 0.017993 | PSNR_gt 20.49 | PSNR_gt_sm 16.65
# [SGD] Iter 00095/03000 | Loss 0.018710 | PSNR_gt 20.15 | PSNR_gt_sm 16.70
# [SGD] Iter 00096/03000 | Loss 0.018390 | PSNR_gt 20.30 | PSNR_gt_sm 16.76
# [SGD] Iter 00097/03000 | Loss 0.017781 | PSNR_gt 20.60 | PSNR_gt_sm 16.81
# [SGD] Iter 00098/03000 | Loss 0.017415 | PSNR_gt 20.79 | PSNR_gt_sm 16.86
# [SGD] Iter 00099/03000 | Loss 0.017433 | PSNR_gt 20.77 | PSNR_gt_sm 16.91
# [SGD] Iter 00100/03000 | Loss 0.017356 | PSNR_gt 20.81 | PSNR_gt_sm 16.96
# [SGD] Iter 00101/03000 | Loss 0.017258 | PSNR_gt 20.86 | PSNR_gt_sm 17.02
# [SGD] Iter 00102/03000 | Loss 0.017290 | PSNR_gt 20.85 | PSNR_gt_sm 17.07
# [SGD] Iter 00103/03000 | Loss 0.017579 | PSNR_gt 20.70 | PSNR_gt_sm 17.12
# [SGD] Iter 00104/03000 | Loss 0.017952 | PSNR_gt 20.51 | PSNR_gt_sm 17.17
# [SGD] Iter 00105/03000 | Loss 0.018404 | PSNR_gt 20.29 | PSNR_gt_sm 17.22
# [SGD] Iter 00106/03000 | Loss 0.017907 | PSNR_gt 20.54 | PSNR_gt_sm 17.26
# [SGD] Iter 00107/03000 | Loss 0.018202 | PSNR_gt 20.38 | PSNR_gt_sm 17.31
# [SGD] Iter 00108/03000 | Loss 0.017650 | PSNR_gt 20.66 | PSNR_gt_sm 17.36
# [SGD] Iter 00109/03000 | Loss 0.017174 | PSNR_gt 20.90 | PSNR_gt_sm 17.41
# [SGD] Iter 00110/03000 | Loss 0.017124 | PSNR_gt 20.93 | PSNR_gt_sm 17.46
# [SGD] Iter 00111/03000 | Loss 0.017306 | PSNR_gt 20.84 | PSNR_gt_sm 17.51
# [SGD] Iter 00112/03000 | Loss 0.017352 | PSNR_gt 20.81 | PSNR_gt_sm 17.55
# [SGD] Iter 00113/03000 | Loss 0.017328 | PSNR_gt 20.83 | PSNR_gt_sm 17.60
# [SGD] Iter 00114/03000 | Loss 0.017648 | PSNR_gt 20.66 | PSNR_gt_sm 17.65
# [SGD] Iter 00115/03000 | Loss 0.017538 | PSNR_gt 20.72 | PSNR_gt_sm 17.70
# [SGD] Iter 00116/03000 | Loss 0.017222 | PSNR_gt 20.88 | PSNR_gt_sm 17.74
# [SGD] Iter 00117/03000 | Loss 0.017104 | PSNR_gt 20.95 | PSNR_gt_sm 17.79
# [SGD] Iter 00118/03000 | Loss 0.017093 | PSNR_gt 20.94 | PSNR_gt_sm 17.83
# [SGD] Iter 00119/03000 | Loss 0.017127 | PSNR_gt 20.94 | PSNR_gt_sm 17.88
# [SGD] Iter 00120/03000 | Loss 0.016929 | PSNR_gt 21.04 | PSNR_gt_sm 17.93
# [SGD] Iter 00121/03000 | Loss 0.016795 | PSNR_gt 21.12 | PSNR_gt_sm 17.97
# [SGD] Iter 00122/03000 | Loss 0.016953 | PSNR_gt 21.03 | PSNR_gt_sm 18.02
# [SGD] Iter 00123/03000 | Loss 0.017390 | PSNR_gt 20.80 | PSNR_gt_sm 18.06
# [SGD] Iter 00124/03000 | Loss 0.016906 | PSNR_gt 21.06 | PSNR_gt_sm 18.11
# [SGD] Iter 00125/03000 | Loss 0.016984 | PSNR_gt 21.02 | PSNR_gt_sm 18.15
# [SGD] Iter 00126/03000 | Loss 0.016883 | PSNR_gt 21.07 | PSNR_gt_sm 18.20
# [SGD] Iter 00127/03000 | Loss 0.017084 | PSNR_gt 20.95 | PSNR_gt_sm 18.24
# [SGD] Iter 00128/03000 | Loss 0.017138 | PSNR_gt 20.93 | PSNR_gt_sm 18.28
# [SGD] Iter 00129/03000 | Loss 0.017102 | PSNR_gt 20.94 | PSNR_gt_sm 18.32
# [SGD] Iter 00130/03000 | Loss 0.017459 | PSNR_gt 20.76 | PSNR_gt_sm 18.37
# [SGD] Iter 00131/03000 | Loss 0.017617 | PSNR_gt 20.68 | PSNR_gt_sm 18.41
# [SGD] Iter 00132/03000 | Loss 0.017845 | PSNR_gt 20.56 | PSNR_gt_sm 18.45
# [SGD] Iter 00133/03000 | Loss 0.017448 | PSNR_gt 20.76 | PSNR_gt_sm 18.48
# [SGD] Iter 00134/03000 | Loss 0.017018 | PSNR_gt 21.00 | PSNR_gt_sm 18.53
# [SGD] Iter 00135/03000 | Loss 0.016785 | PSNR_gt 21.12 | PSNR_gt_sm 18.57
# [SGD] Iter 00136/03000 | Loss 0.016830 | PSNR_gt 21.11 | PSNR_gt_sm 18.61
# [SGD] Iter 00137/03000 | Loss 0.016639 | PSNR_gt 21.20 | PSNR_gt_sm 18.65
# [SGD] Iter 00138/03000 | Loss 0.016798 | PSNR_gt 21.13 | PSNR_gt_sm 18.69
# [SGD] Iter 00139/03000 | Loss 0.016880 | PSNR_gt 21.07 | PSNR_gt_sm 18.73
# [SGD] Iter 00140/03000 | Loss 0.016789 | PSNR_gt 21.13 | PSNR_gt_sm 18.77
# [SGD] Iter 00141/03000 | Loss 0.016761 | PSNR_gt 21.14 | PSNR_gt_sm 18.81
# [SGD] Iter 00142/03000 | Loss 0.016763 | PSNR_gt 21.14 | PSNR_gt_sm 18.85
# [SGD] Iter 00143/03000 | Loss 0.016870 | PSNR_gt 21.07 | PSNR_gt_sm 18.88
# [SGD] Iter 00144/03000 | Loss 0.017299 | PSNR_gt 20.84 | PSNR_gt_sm 18.92
# [SGD] Iter 00145/03000 | Loss 0.017404 | PSNR_gt 20.78 | PSNR_gt_sm 18.96
# [SGD] Iter 00146/03000 | Loss 0.017173 | PSNR_gt 20.91 | PSNR_gt_sm 18.99
# [SGD] Iter 00147/03000 | Loss 0.017064 | PSNR_gt 20.96 | PSNR_gt_sm 19.03
# [SGD] Iter 00148/03000 | Loss 0.016680 | PSNR_gt 21.18 | PSNR_gt_sm 19.07
# [SGD] Iter 00149/03000 | Loss 0.016486 | PSNR_gt 21.30 | PSNR_gt_sm 19.10
# [SGD] Iter 00150/03000 | Loss 0.016333 | PSNR_gt 21.38 | PSNR_gt_sm 19.14
# [SGD] Iter 00151/03000 | Loss 0.016291 | PSNR_gt 21.42 | PSNR_gt_sm 19.18
# [SGD] Iter 00152/03000 | Loss 0.016175 | PSNR_gt 21.48 | PSNR_gt_sm 19.21
# [SGD] Iter 00153/03000 | Loss 0.016182 | PSNR_gt 21.49 | PSNR_gt_sm 19.25
# [SGD] Iter 00154/03000 | Loss 0.016212 | PSNR_gt 21.45 | PSNR_gt_sm 19.28
# [SGD] Iter 00155/03000 | Loss 0.016355 | PSNR_gt 21.38 | PSNR_gt_sm 19.32
# [SGD] Iter 00156/03000 | Loss 0.016409 | PSNR_gt 21.33 | PSNR_gt_sm 19.36
# [SGD] Iter 00157/03000 | Loss 0.016499 | PSNR_gt 21.30 | PSNR_gt_sm 19.39
# [SGD] Iter 00158/03000 | Loss 0.016471 | PSNR_gt 21.30 | PSNR_gt_sm 19.42
# [SGD] Iter 00159/03000 | Loss 0.016742 | PSNR_gt 21.15 | PSNR_gt_sm 19.46
# [SGD] Iter 00160/03000 | Loss 0.016794 | PSNR_gt 21.11 | PSNR_gt_sm 19.49
# [SGD] Iter 00161/03000 | Loss 0.016898 | PSNR_gt 21.06 | PSNR_gt_sm 19.53
# [SGD] Iter 00162/03000 | Loss 0.016366 | PSNR_gt 21.36 | PSNR_gt_sm 19.56
# [SGD] Iter 00163/03000 | Loss 0.016301 | PSNR_gt 21.40 | PSNR_gt_sm 19.59
# [SGD] Iter 00164/03000 | Loss 0.016499 | PSNR_gt 21.28 | PSNR_gt_sm 19.62
# [SGD] Iter 00165/03000 | Loss 0.016714 | PSNR_gt 21.17 | PSNR_gt_sm 19.65
# [SGD] Iter 00166/03000 | Loss 0.016652 | PSNR_gt 21.20 | PSNR_gt_sm 19.68
# [SGD] Iter 00167/03000 | Loss 0.016232 | PSNR_gt 21.44 | PSNR_gt_sm 19.72
# [SGD] Iter 00168/03000 | Loss 0.016247 | PSNR_gt 21.44 | PSNR_gt_sm 19.75
# [SGD] Iter 00169/03000 | Loss 0.016130 | PSNR_gt 21.51 | PSNR_gt_sm 19.78
# [SGD] Iter 00170/03000 | Loss 0.015976 | PSNR_gt 21.60 | PSNR_gt_sm 19.81
# [SGD] Iter 00171/03000 | Loss 0.016005 | PSNR_gt 21.59 | PSNR_gt_sm 19.84
# [SGD] Iter 00172/03000 | Loss 0.016148 | PSNR_gt 21.49 | PSNR_gt_sm 19.87
# [SGD] Iter 00173/03000 | Loss 0.016320 | PSNR_gt 21.39 | PSNR_gt_sm 19.90
# [SGD] Iter 00174/03000 | Loss 0.016448 | PSNR_gt 21.31 | PSNR_gt_sm 19.93
# [SGD] Iter 00175/03000 | Loss 0.016388 | PSNR_gt 21.36 | PSNR_gt_sm 19.96
# [SGD] Iter 00176/03000 | Loss 0.016207 | PSNR_gt 21.45 | PSNR_gt_sm 19.99
# [SGD] Iter 00177/03000 | Loss 0.016080 | PSNR_gt 21.55 | PSNR_gt_sm 20.02
# [SGD] Iter 00178/03000 | Loss 0.015750 | PSNR_gt 21.75 | PSNR_gt_sm 20.05
# [SGD] Iter 00179/03000 | Loss 0.015730 | PSNR_gt 21.76 | PSNR_gt_sm 20.08
# [SGD] Iter 00180/03000 | Loss 0.015841 | PSNR_gt 21.69 | PSNR_gt_sm 20.11
# [SGD] Iter 00181/03000 | Loss 0.016112 | PSNR_gt 21.52 | PSNR_gt_sm 20.14
# [SGD] Iter 00182/03000 | Loss 0.016077 | PSNR_gt 21.54 | PSNR_gt_sm 20.16
# [SGD] Iter 00183/03000 | Loss 0.015908 | PSNR_gt 21.65 | PSNR_gt_sm 20.19
# [SGD] Iter 00184/03000 | Loss 0.016070 | PSNR_gt 21.55 | PSNR_gt_sm 20.22
# [SGD] Iter 00185/03000 | Loss 0.016031 | PSNR_gt 21.57 | PSNR_gt_sm 20.25
# [SGD] Iter 00186/03000 | Loss 0.015975 | PSNR_gt 21.61 | PSNR_gt_sm 20.28
# [SGD] Iter 00187/03000 | Loss 0.015846 | PSNR_gt 21.69 | PSNR_gt_sm 20.30
# [SGD] Iter 00188/03000 | Loss 0.015997 | PSNR_gt 21.59 | PSNR_gt_sm 20.33
# [SGD] Iter 00189/03000 | Loss 0.015876 | PSNR_gt 21.67 | PSNR_gt_sm 20.36
# [SGD] Iter 00190/03000 | Loss 0.015869 | PSNR_gt 21.68 | PSNR_gt_sm 20.38
# [SGD] Iter 00191/03000 | Loss 0.015549 | PSNR_gt 21.88 | PSNR_gt_sm 20.41
# [SGD] Iter 00192/03000 | Loss 0.015626 | PSNR_gt 21.83 | PSNR_gt_sm 20.44
# [SGD] Iter 00193/03000 | Loss 0.015794 | PSNR_gt 21.71 | PSNR_gt_sm 20.46
# [SGD] Iter 00194/03000 | Loss 0.015902 | PSNR_gt 21.65 | PSNR_gt_sm 20.49
# [SGD] Iter 00195/03000 | Loss 0.016123 | PSNR_gt 21.51 | PSNR_gt_sm 20.51
# [SGD] Iter 00196/03000 | Loss 0.016356 | PSNR_gt 21.38 | PSNR_gt_sm 20.54
# [SGD] Iter 00197/03000 | Loss 0.016285 | PSNR_gt 21.40 | PSNR_gt_sm 20.56
# [SGD] Iter 00198/03000 | Loss 0.015851 | PSNR_gt 21.68 | PSNR_gt_sm 20.59
# [SGD] Iter 00199/03000 | Loss 0.015768 | PSNR_gt 21.73 | PSNR_gt_sm 20.61
# [SGD] Iter 00200/03000 | Loss 0.015648 | PSNR_gt 21.83 | PSNR_gt_sm 20.63
# [SGD] Iter 00201/03000 | Loss 0.015539 | PSNR_gt 21.89 | PSNR_gt_sm 20.66
# [SGD] Iter 00202/03000 | Loss 0.015312 | PSNR_gt 22.05 | PSNR_gt_sm 20.68
# [SGD] Iter 00203/03000 | Loss 0.015502 | PSNR_gt 21.91 | PSNR_gt_sm 20.71
# [SGD] Iter 00204/03000 | Loss 0.015591 | PSNR_gt 21.86 | PSNR_gt_sm 20.73
# [SGD] Iter 00205/03000 | Loss 0.015669 | PSNR_gt 21.80 | PSNR_gt_sm 20.75
# [SGD] Iter 00206/03000 | Loss 0.015724 | PSNR_gt 21.77 | PSNR_gt_sm 20.78
# [SGD] Iter 00207/03000 | Loss 0.015852 | PSNR_gt 21.68 | PSNR_gt_sm 20.80
# [SGD] Iter 00208/03000 | Loss 0.016134 | PSNR_gt 21.51 | PSNR_gt_sm 20.82
# [SGD] Iter 00209/03000 | Loss 0.015926 | PSNR_gt 21.63 | PSNR_gt_sm 20.84
# [SGD] Iter 00210/03000 | Loss 0.015680 | PSNR_gt 21.80 | PSNR_gt_sm 20.86
# [SGD] Iter 00211/03000 | Loss 0.015620 | PSNR_gt 21.83 | PSNR_gt_sm 20.88
# [SGD] Iter 00212/03000 | Loss 0.015601 | PSNR_gt 21.85 | PSNR_gt_sm 20.91
# [SGD] Iter 00213/03000 | Loss 0.015725 | PSNR_gt 21.76 | PSNR_gt_sm 20.93
# [SGD] Iter 00214/03000 | Loss 0.015612 | PSNR_gt 21.84 | PSNR_gt_sm 20.95
# [SGD] Iter 00215/03000 | Loss 0.015425 | PSNR_gt 21.96 | PSNR_gt_sm 20.97
# [SGD] Iter 00216/03000 | Loss 0.015405 | PSNR_gt 21.98 | PSNR_gt_sm 20.99
# [SGD] Iter 00217/03000 | Loss 0.015444 | PSNR_gt 21.95 | PSNR_gt_sm 21.01
# [SGD] Iter 00218/03000 | Loss 0.015444 | PSNR_gt 21.95 | PSNR_gt_sm 21.03
# [SGD] Iter 00219/03000 | Loss 0.015212 | PSNR_gt 22.11 | PSNR_gt_sm 21.06
# [SGD] Iter 00220/03000 | Loss 0.015369 | PSNR_gt 22.00 | PSNR_gt_sm 21.08
# [SGD] Iter 00221/03000 | Loss 0.015582 | PSNR_gt 21.86 | PSNR_gt_sm 21.10
# [SGD] Iter 00222/03000 | Loss 0.015897 | PSNR_gt 21.65 | PSNR_gt_sm 21.12
# [SGD] Iter 00223/03000 | Loss 0.015763 | PSNR_gt 21.75 | PSNR_gt_sm 21.14
# [SGD] Iter 00224/03000 | Loss 0.015310 | PSNR_gt 22.04 | PSNR_gt_sm 21.16
# [SGD] Iter 00225/03000 | Loss 0.015336 | PSNR_gt 22.02 | PSNR_gt_sm 21.18
# [SGD] Iter 00226/03000 | Loss 0.015423 | PSNR_gt 21.95 | PSNR_gt_sm 21.20
# [SGD] Iter 00227/03000 | Loss 0.015474 | PSNR_gt 21.94 | PSNR_gt_sm 21.22
# [SGD] Iter 00228/03000 | Loss 0.015430 | PSNR_gt 21.95 | PSNR_gt_sm 21.23
# [SGD] Iter 00229/03000 | Loss 0.015243 | PSNR_gt 22.10 | PSNR_gt_sm 21.25
# [SGD] Iter 00230/03000 | Loss 0.015387 | PSNR_gt 21.98 | PSNR_gt_sm 21.27
# [SGD] Iter 00231/03000 | Loss 0.015455 | PSNR_gt 21.95 | PSNR_gt_sm 21.29
# [SGD] Iter 00232/03000 | Loss 0.015549 | PSNR_gt 21.87 | PSNR_gt_sm 21.31
# [SGD] Iter 00233/03000 | Loss 0.015597 | PSNR_gt 21.86 | PSNR_gt_sm 21.33
# [SGD] Iter 00234/03000 | Loss 0.015329 | PSNR_gt 22.02 | PSNR_gt_sm 21.34
# [SGD] Iter 00235/03000 | Loss 0.015201 | PSNR_gt 22.13 | PSNR_gt_sm 21.36
# [SGD] Iter 00236/03000 | Loss 0.015170 | PSNR_gt 22.13 | PSNR_gt_sm 21.38
# [SGD] Iter 00237/03000 | Loss 0.015356 | PSNR_gt 22.02 | PSNR_gt_sm 21.40
# [SGD] Iter 00238/03000 | Loss 0.015444 | PSNR_gt 21.94 | PSNR_gt_sm 21.42
# [SGD] Iter 00239/03000 | Loss 0.015476 | PSNR_gt 21.95 | PSNR_gt_sm 21.44
# [SGD] Iter 00240/03000 | Loss 0.015181 | PSNR_gt 22.13 | PSNR_gt_sm 21.45
# [SGD] Iter 00241/03000 | Loss 0.015209 | PSNR_gt 22.13 | PSNR_gt_sm 21.47
# [SGD] Iter 00242/03000 | Loss 0.015365 | PSNR_gt 21.99 | PSNR_gt_sm 21.49
# [SGD] Iter 00243/03000 | Loss 0.015259 | PSNR_gt 22.10 | PSNR_gt_sm 21.50
# [SGD] Iter 00244/03000 | Loss 0.015096 | PSNR_gt 22.19 | PSNR_gt_sm 21.52
# [SGD] Iter 00245/03000 | Loss 0.015106 | PSNR_gt 22.19 | PSNR_gt_sm 21.54
# [SGD] Iter 00246/03000 | Loss 0.014969 | PSNR_gt 22.28 | PSNR_gt_sm 21.56
# [SGD] Iter 00247/03000 | Loss 0.015117 | PSNR_gt 22.19 | PSNR_gt_sm 21.57
# [SGD] Iter 00248/03000 | Loss 0.015234 | PSNR_gt 22.09 | PSNR_gt_sm 21.59
# [SGD] Iter 00249/03000 | Loss 0.015429 | PSNR_gt 21.96 | PSNR_gt_sm 21.61
# [SGD] Iter 00250/03000 | Loss 0.015394 | PSNR_gt 21.98 | PSNR_gt_sm 21.62
# [SGD] Iter 00251/03000 | Loss 0.015570 | PSNR_gt 21.86 | PSNR_gt_sm 21.64
# [SGD] Iter 00252/03000 | Loss 0.015939 | PSNR_gt 21.62 | PSNR_gt_sm 21.65
# [SGD] Iter 00253/03000 | Loss 0.015522 | PSNR_gt 21.90 | PSNR_gt_sm 21.66
# [SGD] Iter 00254/03000 | Loss 0.015376 | PSNR_gt 21.99 | PSNR_gt_sm 21.68
# [SGD] Iter 00255/03000 | Loss 0.015130 | PSNR_gt 22.17 | PSNR_gt_sm 21.69
# [SGD] Iter 00256/03000 | Loss 0.015055 | PSNR_gt 22.23 | PSNR_gt_sm 21.71
# [SGD] Iter 00257/03000 | Loss 0.015080 | PSNR_gt 22.21 | PSNR_gt_sm 21.72
# [SGD] Iter 00258/03000 | Loss 0.015036 | PSNR_gt 22.23 | PSNR_gt_sm 21.74
# [SGD] Iter 00259/03000 | Loss 0.014768 | PSNR_gt 22.44 | PSNR_gt_sm 21.75
# [SGD] Iter 00260/03000 | Loss 0.014833 | PSNR_gt 22.38 | PSNR_gt_sm 21.77
# [SGD] Iter 00261/03000 | Loss 0.015003 | PSNR_gt 22.27 | PSNR_gt_sm 21.79
# [SGD] Iter 00262/03000 | Loss 0.015084 | PSNR_gt 22.20 | PSNR_gt_sm 21.80
# [SGD] Iter 00263/03000 | Loss 0.015151 | PSNR_gt 22.16 | PSNR_gt_sm 21.81
# [SGD] Iter 00264/03000 | Loss 0.014899 | PSNR_gt 22.33 | PSNR_gt_sm 21.83
# [SGD] Iter 00265/03000 | Loss 0.014810 | PSNR_gt 22.41 | PSNR_gt_sm 21.84
# [SGD] Iter 00266/03000 | Loss 0.014870 | PSNR_gt 22.35 | PSNR_gt_sm 21.86
# [SGD] Iter 00267/03000 | Loss 0.014795 | PSNR_gt 22.42 | PSNR_gt_sm 21.87
# [SGD] Iter 00268/03000 | Loss 0.014835 | PSNR_gt 22.38 | PSNR_gt_sm 21.89
# [SGD] Iter 00269/03000 | Loss 0.014714 | PSNR_gt 22.48 | PSNR_gt_sm 21.90
# [SGD] Iter 00270/03000 | Loss 0.014853 | PSNR_gt 22.37 | PSNR_gt_sm 21.92
# [SGD] Iter 00271/03000 | Loss 0.014914 | PSNR_gt 22.33 | PSNR_gt_sm 21.93
# [SGD] Iter 00272/03000 | Loss 0.014816 | PSNR_gt 22.39 | PSNR_gt_sm 21.94
# [SGD] Iter 00273/03000 | Loss 0.014932 | PSNR_gt 22.32 | PSNR_gt_sm 21.96
# [SGD] Iter 00274/03000 | Loss 0.015049 | PSNR_gt 22.22 | PSNR_gt_sm 21.97
# [SGD] Iter 00275/03000 | Loss 0.015002 | PSNR_gt 22.27 | PSNR_gt_sm 21.98
# [SGD] Iter 00276/03000 | Loss 0.015020 | PSNR_gt 22.25 | PSNR_gt_sm 22.00
# [SGD] Iter 00277/03000 | Loss 0.015005 | PSNR_gt 22.25 | PSNR_gt_sm 22.01
# [SGD] Iter 00278/03000 | Loss 0.015050 | PSNR_gt 22.23 | PSNR_gt_sm 22.02
# [SGD] Iter 00279/03000 | Loss 0.015071 | PSNR_gt 22.20 | PSNR_gt_sm 22.03
# [SGD] Iter 00280/03000 | Loss 0.015147 | PSNR_gt 22.17 | PSNR_gt_sm 22.05
# [SGD] Iter 00281/03000 | Loss 0.014931 | PSNR_gt 22.30 | PSNR_gt_sm 22.06
# [SGD] Iter 00282/03000 | Loss 0.014711 | PSNR_gt 22.48 | PSNR_gt_sm 22.07
# [SGD] Iter 00283/03000 | Loss 0.014676 | PSNR_gt 22.50 | PSNR_gt_sm 22.09
# [SGD] Iter 00284/03000 | Loss 0.014624 | PSNR_gt 22.55 | PSNR_gt_sm 22.10
# [SGD] Iter 00285/03000 | Loss 0.014552 | PSNR_gt 22.60 | PSNR_gt_sm 22.11
# [SGD] Iter 00286/03000 | Loss 0.014597 | PSNR_gt 22.58 | PSNR_gt_sm 22.13
# [SGD] Iter 00287/03000 | Loss 0.014656 | PSNR_gt 22.51 | PSNR_gt_sm 22.14
# [SGD] Iter 00288/03000 | Loss 0.014656 | PSNR_gt 22.52 | PSNR_gt_sm 22.15
# [SGD] Iter 00289/03000 | Loss 0.014598 | PSNR_gt 22.56 | PSNR_gt_sm 22.16
# [SGD] Iter 00290/03000 | Loss 0.014719 | PSNR_gt 22.48 | PSNR_gt_sm 22.18
# [SGD] Iter 00291/03000 | Loss 0.014664 | PSNR_gt 22.51 | PSNR_gt_sm 22.19
# [SGD] Iter 00292/03000 | Loss 0.014583 | PSNR_gt 22.58 | PSNR_gt_sm 22.20
# [SGD] Iter 00293/03000 | Loss 0.014586 | PSNR_gt 22.57 | PSNR_gt_sm 22.21
# [SGD] Iter 00294/03000 | Loss 0.014663 | PSNR_gt 22.53 | PSNR_gt_sm 22.23
# [SGD] Iter 00295/03000 | Loss 0.014581 | PSNR_gt 22.57 | PSNR_gt_sm 22.24
# [SGD] Iter 00296/03000 | Loss 0.014571 | PSNR_gt 22.60 | PSNR_gt_sm 22.25
# [SGD] Iter 00297/03000 | Loss 0.014596 | PSNR_gt 22.56 | PSNR_gt_sm 22.26
# [SGD] Iter 00298/03000 | Loss 0.014799 | PSNR_gt 22.42 | PSNR_gt_sm 22.27
# [SGD] Iter 00299/03000 | Loss 0.014812 | PSNR_gt 22.39 | PSNR_gt_sm 22.29
# [SGD] Iter 00300/03000 | Loss 0.014991 | PSNR_gt 22.28 | PSNR_gt_sm 22.30
# [SGD] Iter 00301/03000 | Loss 0.014838 | PSNR_gt 22.37 | PSNR_gt_sm 22.31
# [SGD] Iter 00302/03000 | Loss 0.014972 | PSNR_gt 22.29 | PSNR_gt_sm 22.32
# [SGD] Iter 00303/03000 | Loss 0.015011 | PSNR_gt 22.24 | PSNR_gt_sm 22.33
# [SGD] Iter 00304/03000 | Loss 0.014837 | PSNR_gt 22.39 | PSNR_gt_sm 22.34
# [SGD] Iter 00305/03000 | Loss 0.014728 | PSNR_gt 22.45 | PSNR_gt_sm 22.35
# [SGD] Iter 00306/03000 | Loss 0.014657 | PSNR_gt 22.52 | PSNR_gt_sm 22.36
# [SGD] Iter 00307/03000 | Loss 0.014568 | PSNR_gt 22.59 | PSNR_gt_sm 22.37
# [SGD] Iter 00308/03000 | Loss 0.014738 | PSNR_gt 22.45 | PSNR_gt_sm 22.38
# [SGD] Iter 00309/03000 | Loss 0.014733 | PSNR_gt 22.47 | PSNR_gt_sm 22.39
# [SGD] Iter 00310/03000 | Loss 0.014693 | PSNR_gt 22.49 | PSNR_gt_sm 22.40
# [SGD] Iter 00311/03000 | Loss 0.014629 | PSNR_gt 22.54 | PSNR_gt_sm 22.41
# [SGD] Iter 00312/03000 | Loss 0.014598 | PSNR_gt 22.56 | PSNR_gt_sm 22.42
# [SGD] Iter 00313/03000 | Loss 0.014601 | PSNR_gt 22.56 | PSNR_gt_sm 22.43
# [SGD] Iter 00314/03000 | Loss 0.014694 | PSNR_gt 22.48 | PSNR_gt_sm 22.44
# [SGD] Iter 00315/03000 | Loss 0.014889 | PSNR_gt 22.35 | PSNR_gt_sm 22.45
# [SGD] Iter 00316/03000 | Loss 0.014954 | PSNR_gt 22.29 | PSNR_gt_sm 22.46
# [SGD] Iter 00317/03000 | Loss 0.014928 | PSNR_gt 22.32 | PSNR_gt_sm 22.47
# [SGD] Iter 00318/03000 | Loss 0.014705 | PSNR_gt 22.48 | PSNR_gt_sm 22.48
# [SGD] Iter 00319/03000 | Loss 0.014656 | PSNR_gt 22.52 | PSNR_gt_sm 22.49
# [SGD] Iter 00320/03000 | Loss 0.014555 | PSNR_gt 22.59 | PSNR_gt_sm 22.50
# [SGD] Iter 00321/03000 | Loss 0.014522 | PSNR_gt 22.63 | PSNR_gt_sm 22.51
# [SGD] Iter 00322/03000 | Loss 0.014508 | PSNR_gt 22.63 | PSNR_gt_sm 22.52
# [SGD] Iter 00323/03000 | Loss 0.014594 | PSNR_gt 22.57 | PSNR_gt_sm 22.53
# [SGD] Iter 00324/03000 | Loss 0.014509 | PSNR_gt 22.63 | PSNR_gt_sm 22.54
# [SGD] Iter 00325/03000 | Loss 0.014407 | PSNR_gt 22.72 | PSNR_gt_sm 22.55
# [SGD] Iter 00326/03000 | Loss 0.014379 | PSNR_gt 22.74 | PSNR_gt_sm 22.56
# [SGD] Iter 00327/03000 | Loss 0.014517 | PSNR_gt 22.62 | PSNR_gt_sm 22.57
# [SGD] Iter 00328/03000 | Loss 0.014534 | PSNR_gt 22.62 | PSNR_gt_sm 22.58
# [SGD] Iter 00329/03000 | Loss 0.014446 | PSNR_gt 22.68 | PSNR_gt_sm 22.59
# [SGD] Iter 00330/03000 | Loss 0.014516 | PSNR_gt 22.63 | PSNR_gt_sm 22.60
# [SGD] Iter 00331/03000 | Loss 0.014544 | PSNR_gt 22.61 | PSNR_gt_sm 22.61
# [SGD] Iter 00332/03000 | Loss 0.014538 | PSNR_gt 22.61 | PSNR_gt_sm 22.62
# [SGD] Iter 00333/03000 | Loss 0.014556 | PSNR_gt 22.60 | PSNR_gt_sm 22.63
# [SGD] Iter 00334/03000 | Loss 0.014579 | PSNR_gt 22.58 | PSNR_gt_sm 22.63
# [SGD] Iter 00335/03000 | Loss 0.014449 | PSNR_gt 22.69 | PSNR_gt_sm 22.64
# [SGD] Iter 00336/03000 | Loss 0.014427 | PSNR_gt 22.69 | PSNR_gt_sm 22.65
# [SGD] Iter 00337/03000 | Loss 0.014455 | PSNR_gt 22.69 | PSNR_gt_sm 22.66
# [SGD] Iter 00338/03000 | Loss 0.014354 | PSNR_gt 22.75 | PSNR_gt_sm 22.67
# [SGD] Iter 00339/03000 | Loss 0.014557 | PSNR_gt 22.61 | PSNR_gt_sm 22.68
# [SGD] Iter 00340/03000 | Loss 0.014700 | PSNR_gt 22.48 | PSNR_gt_sm 22.69
# [SGD] Iter 00341/03000 | Loss 0.014631 | PSNR_gt 22.55 | PSNR_gt_sm 22.69
# [SGD] Iter 00342/03000 | Loss 0.014487 | PSNR_gt 22.64 | PSNR_gt_sm 22.70
# [SGD] Iter 00343/03000 | Loss 0.014641 | PSNR_gt 22.53 | PSNR_gt_sm 22.71
# [SGD] Iter 00344/03000 | Loss 0.014527 | PSNR_gt 22.61 | PSNR_gt_sm 22.72
# [SGD] Iter 00345/03000 | Loss 0.014415 | PSNR_gt 22.72 | PSNR_gt_sm 22.73
# [SGD] Iter 00346/03000 | Loss 0.014409 | PSNR_gt 22.71 | PSNR_gt_sm 22.74
# [SGD] Iter 00347/03000 | Loss 0.014403 | PSNR_gt 22.73 | PSNR_gt_sm 22.74
# [SGD] Iter 00348/03000 | Loss 0.014364 | PSNR_gt 22.75 | PSNR_gt_sm 22.75
# [SGD] Iter 00349/03000 | Loss 0.014248 | PSNR_gt 22.85 | PSNR_gt_sm 22.76
# [SGD] Iter 00350/03000 | Loss 0.014122 | PSNR_gt 22.95 | PSNR_gt_sm 22.77
# [SGD] Iter 00351/03000 | Loss 0.014032 | PSNR_gt 23.03 | PSNR_gt_sm 22.78
# [SGD] Iter 00352/03000 | Loss 0.014140 | PSNR_gt 22.93 | PSNR_gt_sm 22.79
# [SGD] Iter 00353/03000 | Loss 0.014108 | PSNR_gt 22.97 | PSNR_gt_sm 22.80
# [SGD] Iter 00354/03000 | Loss 0.014155 | PSNR_gt 22.93 | PSNR_gt_sm 22.81
# [SGD] Iter 00355/03000 | Loss 0.014089 | PSNR_gt 22.99 | PSNR_gt_sm 22.82
# [SGD] Iter 00356/03000 | Loss 0.014125 | PSNR_gt 22.96 | PSNR_gt_sm 22.83
# [SGD] Iter 00357/03000 | Loss 0.014020 | PSNR_gt 23.04 | PSNR_gt_sm 22.84
# [SGD] Iter 00358/03000 | Loss 0.014113 | PSNR_gt 22.96 | PSNR_gt_sm 22.85
# [SGD] Iter 00359/03000 | Loss 0.014263 | PSNR_gt 22.83 | PSNR_gt_sm 22.85
# [SGD] Iter 00360/03000 | Loss 0.014269 | PSNR_gt 22.83 | PSNR_gt_sm 22.86
# [SGD] Iter 00361/03000 | Loss 0.014450 | PSNR_gt 22.67 | PSNR_gt_sm 22.87
# [SGD] Iter 00362/03000 | Loss 0.014142 | PSNR_gt 22.95 | PSNR_gt_sm 22.88
# [SGD] Iter 00363/03000 | Loss 0.014057 | PSNR_gt 23.00 | PSNR_gt_sm 22.89
# [SGD] Iter 00364/03000 | Loss 0.013993 | PSNR_gt 23.07 | PSNR_gt_sm 22.90
# [SGD] Iter 00365/03000 | Loss 0.014009 | PSNR_gt 23.05 | PSNR_gt_sm 22.90
# [SGD] Iter 00366/03000 | Loss 0.014107 | PSNR_gt 22.97 | PSNR_gt_sm 22.91
# [SGD] Iter 00367/03000 | Loss 0.014044 | PSNR_gt 23.01 | PSNR_gt_sm 22.92
# [SGD] Iter 00368/03000 | Loss 0.014130 | PSNR_gt 22.95 | PSNR_gt_sm 22.93
# [SGD] Iter 00369/03000 | Loss 0.014117 | PSNR_gt 22.95 | PSNR_gt_sm 22.94
# [SGD] Iter 00370/03000 | Loss 0.014054 | PSNR_gt 23.02 | PSNR_gt_sm 22.95
# [SGD] Iter 00371/03000 | Loss 0.014036 | PSNR_gt 23.02 | PSNR_gt_sm 22.96
# [SGD] Iter 00372/03000 | Loss 0.014071 | PSNR_gt 23.01 | PSNR_gt_sm 22.97
# [SGD] Iter 00373/03000 | Loss 0.014048 | PSNR_gt 23.01 | PSNR_gt_sm 22.97
# [SGD] Iter 00374/03000 | Loss 0.014256 | PSNR_gt 22.84 | PSNR_gt_sm 22.98
# [SGD] Iter 00375/03000 | Loss 0.014371 | PSNR_gt 22.73 | PSNR_gt_sm 22.99
# [SGD] Iter 00376/03000 | Loss 0.014379 | PSNR_gt 22.75 | PSNR_gt_sm 23.00
# [SGD] Iter 00377/03000 | Loss 0.014340 | PSNR_gt 22.76 | PSNR_gt_sm 23.00
# [SGD] Iter 00378/03000 | Loss 0.014383 | PSNR_gt 22.74 | PSNR_gt_sm 23.01
# [SGD] Iter 00379/03000 | Loss 0.014197 | PSNR_gt 22.88 | PSNR_gt_sm 23.02
# [SGD] Iter 00380/03000 | Loss 0.014142 | PSNR_gt 22.94 | PSNR_gt_sm 23.03
# [SGD] Iter 00381/03000 | Loss 0.014169 | PSNR_gt 22.90 | PSNR_gt_sm 23.03
# [SGD] Iter 00382/03000 | Loss 0.014308 | PSNR_gt 22.80 | PSNR_gt_sm 23.04
# [SGD] Iter 00383/03000 | Loss 0.014384 | PSNR_gt 22.73 | PSNR_gt_sm 23.05
# [SGD] Iter 00384/03000 | Loss 0.014490 | PSNR_gt 22.65 | PSNR_gt_sm 23.05
# [SGD] Iter 00385/03000 | Loss 0.014376 | PSNR_gt 22.74 | PSNR_gt_sm 23.06
# [SGD] Iter 00386/03000 | Loss 0.014270 | PSNR_gt 22.82 | PSNR_gt_sm 23.07
# [SGD] Iter 00387/03000 | Loss 0.014188 | PSNR_gt 22.91 | PSNR_gt_sm 23.07
# [SGD] Iter 00388/03000 | Loss 0.014116 | PSNR_gt 22.95 | PSNR_gt_sm 23.08
# [SGD] Iter 00389/03000 | Loss 0.014000 | PSNR_gt 23.06 | PSNR_gt_sm 23.09
# [SGD] Iter 00390/03000 | Loss 0.013877 | PSNR_gt 23.16 | PSNR_gt_sm 23.09
# [SGD] Iter 00391/03000 | Loss 0.013859 | PSNR_gt 23.20 | PSNR_gt_sm 23.10
# [SGD] Iter 00392/03000 | Loss 0.013736 | PSNR_gt 23.29 | PSNR_gt_sm 23.11
# [SGD] Iter 00393/03000 | Loss 0.013722 | PSNR_gt 23.31 | PSNR_gt_sm 23.12
# [SGD] Iter 00394/03000 | Loss 0.013780 | PSNR_gt 23.25 | PSNR_gt_sm 23.13
# [SGD] Iter 00395/03000 | Loss 0.013815 | PSNR_gt 23.23 | PSNR_gt_sm 23.13
# [SGD] Iter 00396/03000 | Loss 0.013837 | PSNR_gt 23.20 | PSNR_gt_sm 23.14
# [SGD] Iter 00397/03000 | Loss 0.013799 | PSNR_gt 23.24 | PSNR_gt_sm 23.15
# [SGD] Iter 00398/03000 | Loss 0.013837 | PSNR_gt 23.21 | PSNR_gt_sm 23.16
# [SGD] Iter 00399/03000 | Loss 0.013857 | PSNR_gt 23.19 | PSNR_gt_sm 23.17
# [SGD] Iter 00400/03000 | Loss 0.013983 | PSNR_gt 23.07 | PSNR_gt_sm 23.17
# [SGD] Iter 00401/03000 | Loss 0.013943 | PSNR_gt 23.11 | PSNR_gt_sm 23.18
# [SGD] Iter 00402/03000 | Loss 0.013952 | PSNR_gt 23.10 | PSNR_gt_sm 23.19
# [SGD] Iter 00403/03000 | Loss 0.013861 | PSNR_gt 23.19 | PSNR_gt_sm 23.19
# [SGD] Iter 00404/03000 | Loss 0.013804 | PSNR_gt 23.22 | PSNR_gt_sm 23.20
# [SGD] Iter 00405/03000 | Loss 0.013929 | PSNR_gt 23.13 | PSNR_gt_sm 23.21
# [SGD] Iter 00406/03000 | Loss 0.013974 | PSNR_gt 23.07 | PSNR_gt_sm 23.22
# [SGD] Iter 00407/03000 | Loss 0.014005 | PSNR_gt 23.06 | PSNR_gt_sm 23.23
# [SGD] Iter 00408/03000 | Loss 0.013807 | PSNR_gt 23.22 | PSNR_gt_sm 23.23
# [SGD] Iter 00409/03000 | Loss 0.013764 | PSNR_gt 23.28 | PSNR_gt_sm 23.24
# [SGD] Iter 00410/03000 | Loss 0.013799 | PSNR_gt 23.23 | PSNR_gt_sm 23.25
# [SGD] Iter 00411/03000 | Loss 0.013910 | PSNR_gt 23.14 | PSNR_gt_sm 23.26
# [SGD] Iter 00412/03000 | Loss 0.014015 | PSNR_gt 23.03 | PSNR_gt_sm 23.26
# [SGD] Iter 00413/03000 | Loss 0.013868 | PSNR_gt 23.18 | PSNR_gt_sm 23.27
# [SGD] Iter 00414/03000 | Loss 0.013747 | PSNR_gt 23.28 | PSNR_gt_sm 23.28
# [SGD] Iter 00415/03000 | Loss 0.013750 | PSNR_gt 23.29 | PSNR_gt_sm 23.28
# [SGD] Iter 00416/03000 | Loss 0.013893 | PSNR_gt 23.15 | PSNR_gt_sm 23.29
# [SGD] Iter 00417/03000 | Loss 0.013959 | PSNR_gt 23.09 | PSNR_gt_sm 23.30
# [SGD] Iter 00418/03000 | Loss 0.013781 | PSNR_gt 23.25 | PSNR_gt_sm 23.30
# [SGD] Iter 00419/03000 | Loss 0.013819 | PSNR_gt 23.22 | PSNR_gt_sm 23.31
# [SGD] Iter 00420/03000 | Loss 0.013773 | PSNR_gt 23.26 | PSNR_gt_sm 23.32
# [SGD] Iter 00421/03000 | Loss 0.013794 | PSNR_gt 23.24 | PSNR_gt_sm 23.33
# [SGD] Iter 00422/03000 | Loss 0.013733 | PSNR_gt 23.29 | PSNR_gt_sm 23.33
# [SGD] Iter 00423/03000 | Loss 0.013802 | PSNR_gt 23.24 | PSNR_gt_sm 23.34
# [SGD] Iter 00424/03000 | Loss 0.013827 | PSNR_gt 23.20 | PSNR_gt_sm 23.35
# [SGD] Iter 00425/03000 | Loss 0.013806 | PSNR_gt 23.25 | PSNR_gt_sm 23.35
# [SGD] Iter 00426/03000 | Loss 0.013759 | PSNR_gt 23.26 | PSNR_gt_sm 23.36
# [SGD] Iter 00427/03000 | Loss 0.013864 | PSNR_gt 23.19 | PSNR_gt_sm 23.37
# [SGD] Iter 00428/03000 | Loss 0.013850 | PSNR_gt 23.18 | PSNR_gt_sm 23.37
# [SGD] Iter 00429/03000 | Loss 0.014010 | PSNR_gt 23.05 | PSNR_gt_sm 23.38
# [SGD] Iter 00430/03000 | Loss 0.014087 | PSNR_gt 22.97 | PSNR_gt_sm 23.39
# [SGD] Iter 00431/03000 | Loss 0.014087 | PSNR_gt 22.99 | PSNR_gt_sm 23.39
# [SGD] Iter 00432/03000 | Loss 0.014018 | PSNR_gt 23.03 | PSNR_gt_sm 23.40
# [SGD] Iter 00433/03000 | Loss 0.013873 | PSNR_gt 23.17 | PSNR_gt_sm 23.40
# [SGD] Iter 00434/03000 | Loss 0.013867 | PSNR_gt 23.17 | PSNR_gt_sm 23.41
# [SGD] Iter 00435/03000 | Loss 0.013891 | PSNR_gt 23.15 | PSNR_gt_sm 23.42
# [SGD] Iter 00436/03000 | Loss 0.013770 | PSNR_gt 23.26 | PSNR_gt_sm 23.42
# [SGD] Iter 00437/03000 | Loss 0.013701 | PSNR_gt 23.34 | PSNR_gt_sm 23.43
# [SGD] Iter 00438/03000 | Loss 0.013617 | PSNR_gt 23.40 | PSNR_gt_sm 23.44
# [SGD] Iter 00439/03000 | Loss 0.013665 | PSNR_gt 23.36 | PSNR_gt_sm 23.44
# [SGD] Iter 00440/03000 | Loss 0.013566 | PSNR_gt 23.45 | PSNR_gt_sm 23.45
# [SGD] Iter 00441/03000 | Loss 0.013569 | PSNR_gt 23.46 | PSNR_gt_sm 23.46
# [SGD] Iter 00442/03000 | Loss 0.013569 | PSNR_gt 23.45 | PSNR_gt_sm 23.46
# [SGD] Iter 00443/03000 | Loss 0.013601 | PSNR_gt 23.42 | PSNR_gt_sm 23.47
# [SGD] Iter 00444/03000 | Loss 0.013700 | PSNR_gt 23.33 | PSNR_gt_sm 23.48
# [SGD] Iter 00445/03000 | Loss 0.013693 | PSNR_gt 23.35 | PSNR_gt_sm 23.48
# [SGD] Iter 00446/03000 | Loss 0.013719 | PSNR_gt 23.30 | PSNR_gt_sm 23.49
# [SGD] Iter 00447/03000 | Loss 0.013714 | PSNR_gt 23.31 | PSNR_gt_sm 23.50
# [SGD] Iter 00448/03000 | Loss 0.013684 | PSNR_gt 23.34 | PSNR_gt_sm 23.50
# [SGD] Iter 00449/03000 | Loss 0.013748 | PSNR_gt 23.29 | PSNR_gt_sm 23.51
# [SGD] Iter 00450/03000 | Loss 0.013773 | PSNR_gt 23.25 | PSNR_gt_sm 23.51
# [SGD] Iter 00451/03000 | Loss 0.013741 | PSNR_gt 23.29 | PSNR_gt_sm 23.52
# [SGD] Iter 00452/03000 | Loss 0.013680 | PSNR_gt 23.34 | PSNR_gt_sm 23.53
# [SGD] Iter 00453/03000 | Loss 0.013734 | PSNR_gt 23.30 | PSNR_gt_sm 23.53
# [SGD] Iter 00454/03000 | Loss 0.013675 | PSNR_gt 23.35 | PSNR_gt_sm 23.54
# [SGD] Iter 00455/03000 | Loss 0.013597 | PSNR_gt 23.43 | PSNR_gt_sm 23.54
# [SGD] Iter 00456/03000 | Loss 0.013623 | PSNR_gt 23.39 | PSNR_gt_sm 23.55
# [SGD] Iter 00457/03000 | Loss 0.013667 | PSNR_gt 23.36 | PSNR_gt_sm 23.56
# [SGD] Iter 00458/03000 | Loss 0.013594 | PSNR_gt 23.42 | PSNR_gt_sm 23.56
# [SGD] Iter 00459/03000 | Loss 0.013758 | PSNR_gt 23.28 | PSNR_gt_sm 23.57
# [SGD] Iter 00460/03000 | Loss 0.013674 | PSNR_gt 23.35 | PSNR_gt_sm 23.57
# [SGD] Iter 00461/03000 | Loss 0.013690 | PSNR_gt 23.33 | PSNR_gt_sm 23.58
# [SGD] Iter 00462/03000 | Loss 0.013720 | PSNR_gt 23.29 | PSNR_gt_sm 23.59
# [SGD] Iter 00463/03000 | Loss 0.013857 | PSNR_gt 23.19 | PSNR_gt_sm 23.59
# [SGD] Iter 00464/03000 | Loss 0.013815 | PSNR_gt 23.22 | PSNR_gt_sm 23.60
# [SGD] Iter 00465/03000 | Loss 0.013765 | PSNR_gt 23.27 | PSNR_gt_sm 23.60
# [SGD] Iter 00466/03000 | Loss 0.013759 | PSNR_gt 23.27 | PSNR_gt_sm 23.61
# [SGD] Iter 00467/03000 | Loss 0.013852 | PSNR_gt 23.18 | PSNR_gt_sm 23.61
# [SGD] Iter 00468/03000 | Loss 0.013783 | PSNR_gt 23.25 | PSNR_gt_sm 23.62
# [SGD] Iter 00469/03000 | Loss 0.013646 | PSNR_gt 23.39 | PSNR_gt_sm 23.63
# [SGD] Iter 00470/03000 | Loss 0.013560 | PSNR_gt 23.46 | PSNR_gt_sm 23.63
# [SGD] Iter 00471/03000 | Loss 0.013448 | PSNR_gt 23.56 | PSNR_gt_sm 23.64
# [SGD] Iter 00472/03000 | Loss 0.013409 | PSNR_gt 23.61 | PSNR_gt_sm 23.64
# [SGD] Iter 00473/03000 | Loss 0.013458 | PSNR_gt 23.56 | PSNR_gt_sm 23.65
# [SGD] Iter 00474/03000 | Loss 0.013571 | PSNR_gt 23.45 | PSNR_gt_sm 23.66
# [SGD] Iter 00475/03000 | Loss 0.013557 | PSNR_gt 23.46 | PSNR_gt_sm 23.66
# [SGD] Iter 00476/03000 | Loss 0.013507 | PSNR_gt 23.52 | PSNR_gt_sm 23.67
# [SGD] Iter 00477/03000 | Loss 0.013515 | PSNR_gt 23.49 | PSNR_gt_sm 23.67
# [SGD] Iter 00478/03000 | Loss 0.013582 | PSNR_gt 23.44 | PSNR_gt_sm 23.68
# [SGD] Iter 00479/03000 | Loss 0.013519 | PSNR_gt 23.49 | PSNR_gt_sm 23.69
# [SGD] Iter 00480/03000 | Loss 0.013471 | PSNR_gt 23.54 | PSNR_gt_sm 23.69
# [SGD] Iter 00481/03000 | Loss 0.013452 | PSNR_gt 23.55 | PSNR_gt_sm 23.70
# [SGD] Iter 00482/03000 | Loss 0.013509 | PSNR_gt 23.51 | PSNR_gt_sm 23.70
# [SGD] Iter 00483/03000 | Loss 0.013433 | PSNR_gt 23.58 | PSNR_gt_sm 23.71
# [SGD] Iter 00484/03000 | Loss 0.013529 | PSNR_gt 23.50 | PSNR_gt_sm 23.72
# [SGD] Iter 00485/03000 | Loss 0.013517 | PSNR_gt 23.49 | PSNR_gt_sm 23.72
# [SGD] Iter 00486/03000 | Loss 0.013606 | PSNR_gt 23.43 | PSNR_gt_sm 23.73
# [SGD] Iter 00487/03000 | Loss 0.013662 | PSNR_gt 23.35 | PSNR_gt_sm 23.73
# [SGD] Iter 00488/03000 | Loss 0.013718 | PSNR_gt 23.32 | PSNR_gt_sm 23.74
# [SGD] Iter 00489/03000 | Loss 0.013743 | PSNR_gt 23.27 | PSNR_gt_sm 23.74
# [SGD] Iter 00490/03000 | Loss 0.013616 | PSNR_gt 23.41 | PSNR_gt_sm 23.75
# [SGD] Iter 00491/03000 | Loss 0.013517 | PSNR_gt 23.49 | PSNR_gt_sm 23.75
# [SGD] Iter 00492/03000 | Loss 0.013425 | PSNR_gt 23.60 | PSNR_gt_sm 23.76
# [SGD] Iter 00493/03000 | Loss 0.013438 | PSNR_gt 23.57 | PSNR_gt_sm 23.76
# [SGD] Iter 00494/03000 | Loss 0.013446 | PSNR_gt 23.58 | PSNR_gt_sm 23.77
# [SGD] Iter 00495/03000 | Loss 0.013549 | PSNR_gt 23.46 | PSNR_gt_sm 23.78
# [SGD] Iter 00496/03000 | Loss 0.013464 | PSNR_gt 23.56 | PSNR_gt_sm 23.78
# [SGD] Iter 00497/03000 | Loss 0.013410 | PSNR_gt 23.59 | PSNR_gt_sm 23.79
# [SGD] Iter 00498/03000 | Loss 0.013320 | PSNR_gt 23.70 | PSNR_gt_sm 23.79
# [SGD] Iter 00499/03000 | Loss 0.013307 | PSNR_gt 23.69 | PSNR_gt_sm 23.80
# [SGD] Iter 00500/03000 | Loss 0.013308 | PSNR_gt 23.72 | PSNR_gt_sm 23.81
# [SGD] Iter 00501/03000 | Loss 0.013359 | PSNR_gt 23.65 | PSNR_gt_sm 23.81
# [SGD] Iter 00502/03000 | Loss 0.013480 | PSNR_gt 23.55 | PSNR_gt_sm 23.82
# [SGD] Iter 00503/03000 | Loss 0.013416 | PSNR_gt 23.58 | PSNR_gt_sm 23.82
# [SGD] Iter 00504/03000 | Loss 0.013435 | PSNR_gt 23.59 | PSNR_gt_sm 23.83
# [SGD] Iter 00505/03000 | Loss 0.013430 | PSNR_gt 23.57 | PSNR_gt_sm 23.83
# [SGD] Iter 00506/03000 | Loss 0.013533 | PSNR_gt 23.50 | PSNR_gt_sm 23.84
# [SGD] Iter 00507/03000 | Loss 0.013380 | PSNR_gt 23.62 | PSNR_gt_sm 23.85
# [SGD] Iter 00508/03000 | Loss 0.013455 | PSNR_gt 23.57 | PSNR_gt_sm 23.85
# [SGD] Iter 00509/03000 | Loss 0.013327 | PSNR_gt 23.68 | PSNR_gt_sm 23.86
# [SGD] Iter 00510/03000 | Loss 0.013444 | PSNR_gt 23.58 | PSNR_gt_sm 23.86
# [SGD] Iter 00511/03000 | Loss 0.013385 | PSNR_gt 23.63 | PSNR_gt_sm 23.87
# [SGD] Iter 00512/03000 | Loss 0.013416 | PSNR_gt 23.60 | PSNR_gt_sm 23.87
# [SGD] Iter 00513/03000 | Loss 0.013397 | PSNR_gt 23.60 | PSNR_gt_sm 23.88
# [SGD] Iter 00514/03000 | Loss 0.013447 | PSNR_gt 23.59 | PSNR_gt_sm 23.89
# [SGD] Iter 00515/03000 | Loss 0.013369 | PSNR_gt 23.63 | PSNR_gt_sm 23.89
# [SGD] Iter 00516/03000 | Loss 0.013281 | PSNR_gt 23.74 | PSNR_gt_sm 23.90
# [SGD] Iter 00517/03000 | Loss 0.013304 | PSNR_gt 23.70 | PSNR_gt_sm 23.90
# [SGD] Iter 00518/03000 | Loss 0.013426 | PSNR_gt 23.59 | PSNR_gt_sm 23.91
# [SGD] Iter 00519/03000 | Loss 0.013394 | PSNR_gt 23.62 | PSNR_gt_sm 23.91
# [SGD] Iter 00520/03000 | Loss 0.013413 | PSNR_gt 23.59 | PSNR_gt_sm 23.92
# [SGD] Iter 00521/03000 | Loss 0.013472 | PSNR_gt 23.55 | PSNR_gt_sm 23.93
# [SGD] Iter 00522/03000 | Loss 0.013344 | PSNR_gt 23.66 | PSNR_gt_sm 23.93
# [SGD] Iter 00523/03000 | Loss 0.013267 | PSNR_gt 23.75 | PSNR_gt_sm 23.94
# [SGD] Iter 00524/03000 | Loss 0.013280 | PSNR_gt 23.73 | PSNR_gt_sm 23.94
# [SGD] Iter 00525/03000 | Loss 0.013221 | PSNR_gt 23.79 | PSNR_gt_sm 23.95
# [SGD] Iter 00526/03000 | Loss 0.013297 | PSNR_gt 23.71 | PSNR_gt_sm 23.95
# [SGD] Iter 00527/03000 | Loss 0.013315 | PSNR_gt 23.71 | PSNR_gt_sm 23.96
# [SGD] Iter 00528/03000 | Loss 0.013346 | PSNR_gt 23.65 | PSNR_gt_sm 23.96
# [SGD] Iter 00529/03000 | Loss 0.013451 | PSNR_gt 23.57 | PSNR_gt_sm 23.97
# [SGD] Iter 00530/03000 | Loss 0.013712 | PSNR_gt 23.29 | PSNR_gt_sm 23.97
# [SGD] Iter 00531/03000 | Loss 0.013868 | PSNR_gt 23.19 | PSNR_gt_sm 23.98
# [SGD] Iter 00532/03000 | Loss 0.013705 | PSNR_gt 23.30 | PSNR_gt_sm 23.98
# [SGD] Iter 00533/03000 | Loss 0.013370 | PSNR_gt 23.66 | PSNR_gt_sm 23.98
# [SGD] Iter 00534/03000 | Loss 0.013256 | PSNR_gt 23.76 | PSNR_gt_sm 23.99
# [SGD] Iter 00535/03000 | Loss 0.013258 | PSNR_gt 23.77 | PSNR_gt_sm 23.99
# [SGD] Iter 00536/03000 | Loss 0.013149 | PSNR_gt 23.87 | PSNR_gt_sm 24.00
# [SGD] Iter 00537/03000 | Loss 0.013133 | PSNR_gt 23.89 | PSNR_gt_sm 24.00
# [SGD] Iter 00538/03000 | Loss 0.013236 | PSNR_gt 23.77 | PSNR_gt_sm 24.01
# [SGD] Iter 00539/03000 | Loss 0.013342 | PSNR_gt 23.67 | PSNR_gt_sm 24.01
# [SGD] Iter 00540/03000 | Loss 0.013188 | PSNR_gt 23.82 | PSNR_gt_sm 24.02
# [SGD] Iter 00541/03000 | Loss 0.013157 | PSNR_gt 23.86 | PSNR_gt_sm 24.03
# [SGD] Iter 00542/03000 | Loss 0.013130 | PSNR_gt 23.89 | PSNR_gt_sm 24.03
# [SGD] Iter 00543/03000 | Loss 0.013141 | PSNR_gt 23.88 | PSNR_gt_sm 24.04
# [SGD] Iter 00544/03000 | Loss 0.013091 | PSNR_gt 23.94 | PSNR_gt_sm 24.04
# [SGD] Iter 00545/03000 | Loss 0.013181 | PSNR_gt 23.83 | PSNR_gt_sm 24.05
# [SGD] Iter 00546/03000 | Loss 0.013191 | PSNR_gt 23.82 | PSNR_gt_sm 24.05
# [SGD] Iter 00547/03000 | Loss 0.013298 | PSNR_gt 23.71 | PSNR_gt_sm 24.06
# [SGD] Iter 00548/03000 | Loss 0.013367 | PSNR_gt 23.65 | PSNR_gt_sm 24.06
# [SGD] Iter 00549/03000 | Loss 0.013445 | PSNR_gt 23.56 | PSNR_gt_sm 24.07
# [SGD] Iter 00550/03000 | Loss 0.013407 | PSNR_gt 23.61 | PSNR_gt_sm 24.07
# [SGD] Iter 00551/03000 | Loss 0.013399 | PSNR_gt 23.61 | PSNR_gt_sm 24.08
# [SGD] Iter 00552/03000 | Loss 0.013381 | PSNR_gt 23.64 | PSNR_gt_sm 24.08
# [SGD] Iter 00553/03000 | Loss 0.013147 | PSNR_gt 23.86 | PSNR_gt_sm 24.09
# [SGD] Iter 00554/03000 | Loss 0.013154 | PSNR_gt 23.87 | PSNR_gt_sm 24.09
# [SGD] Iter 00555/03000 | Loss 0.013099 | PSNR_gt 23.92 | PSNR_gt_sm 24.10
# [SGD] Iter 00556/03000 | Loss 0.013103 | PSNR_gt 23.93 | PSNR_gt_sm 24.10
# [SGD] Iter 00557/03000 | Loss 0.013135 | PSNR_gt 23.88 | PSNR_gt_sm 24.11
# [SGD] Iter 00558/03000 | Loss 0.013136 | PSNR_gt 23.89 | PSNR_gt_sm 24.11
# [SGD] Iter 00559/03000 | Loss 0.013121 | PSNR_gt 23.90 | PSNR_gt_sm 24.12
# [SGD] Iter 00560/03000 | Loss 0.013180 | PSNR_gt 23.84 | PSNR_gt_sm 24.12
# [SGD] Iter 00561/03000 | Loss 0.013169 | PSNR_gt 23.85 | PSNR_gt_sm 24.13
# [SGD] Iter 00562/03000 | Loss 0.013215 | PSNR_gt 23.80 | PSNR_gt_sm 24.13
# [SGD] Iter 00563/03000 | Loss 0.013084 | PSNR_gt 23.94 | PSNR_gt_sm 24.14
# [SGD] Iter 00564/03000 | Loss 0.013145 | PSNR_gt 23.88 | PSNR_gt_sm 24.15
# [SGD] Iter 00565/03000 | Loss 0.013108 | PSNR_gt 23.90 | PSNR_gt_sm 24.15
# [SGD] Iter 00566/03000 | Loss 0.013151 | PSNR_gt 23.87 | PSNR_gt_sm 24.16
# [SGD] Iter 00567/03000 | Loss 0.013158 | PSNR_gt 23.85 | PSNR_gt_sm 24.16
# [SGD] Iter 00568/03000 | Loss 0.013116 | PSNR_gt 23.91 | PSNR_gt_sm 24.17
# [SGD] Iter 00569/03000 | Loss 0.013153 | PSNR_gt 23.86 | PSNR_gt_sm 24.17
# [SGD] Iter 00570/03000 | Loss 0.013166 | PSNR_gt 23.86 | PSNR_gt_sm 24.18
# [SGD] Iter 00571/03000 | Loss 0.013191 | PSNR_gt 23.83 | PSNR_gt_sm 24.18
# [SGD] Iter 00572/03000 | Loss 0.013172 | PSNR_gt 23.84 | PSNR_gt_sm 24.19
# [SGD] Iter 00573/03000 | Loss 0.013218 | PSNR_gt 23.80 | PSNR_gt_sm 24.19
# [SGD] Iter 00574/03000 | Loss 0.013291 | PSNR_gt 23.72 | PSNR_gt_sm 24.19
# [SGD] Iter 00575/03000 | Loss 0.013261 | PSNR_gt 23.75 | PSNR_gt_sm 24.20
# [SGD] Iter 00576/03000 | Loss 0.013263 | PSNR_gt 23.74 | PSNR_gt_sm 24.20
# [SGD] Iter 00577/03000 | Loss 0.013280 | PSNR_gt 23.73 | PSNR_gt_sm 24.21
# [SGD] Iter 00578/03000 | Loss 0.013273 | PSNR_gt 23.73 | PSNR_gt_sm 24.21
# [SGD] Iter 00579/03000 | Loss 0.013242 | PSNR_gt 23.78 | PSNR_gt_sm 24.22
# [SGD] Iter 00580/03000 | Loss 0.013054 | PSNR_gt 23.96 | PSNR_gt_sm 24.22
# [SGD] Iter 00581/03000 | Loss 0.013028 | PSNR_gt 24.00 | PSNR_gt_sm 24.23
# [SGD] Iter 00582/03000 | Loss 0.012929 | PSNR_gt 24.10 | PSNR_gt_sm 24.23
# [SGD] Iter 00583/03000 | Loss 0.012953 | PSNR_gt 24.08 | PSNR_gt_sm 24.24
# [SGD] Iter 00584/03000 | Loss 0.012992 | PSNR_gt 24.02 | PSNR_gt_sm 24.24
# [SGD] Iter 00585/03000 | Loss 0.012985 | PSNR_gt 24.05 | PSNR_gt_sm 24.25
# [SGD] Iter 00586/03000 | Loss 0.013099 | PSNR_gt 23.91 | PSNR_gt_sm 24.25
# [SGD] Iter 00587/03000 | Loss 0.013045 | PSNR_gt 23.99 | PSNR_gt_sm 24.26
# [SGD] Iter 00588/03000 | Loss 0.012949 | PSNR_gt 24.07 | PSNR_gt_sm 24.26
# [SGD] Iter 00589/03000 | Loss 0.013046 | PSNR_gt 23.98 | PSNR_gt_sm 24.27
# [SGD] Iter 00590/03000 | Loss 0.013024 | PSNR_gt 24.00 | PSNR_gt_sm 24.27
# [SGD] Iter 00591/03000 | Loss 0.013054 | PSNR_gt 23.98 | PSNR_gt_sm 24.28
# [SGD] Iter 00592/03000 | Loss 0.013038 | PSNR_gt 23.97 | PSNR_gt_sm 24.28
# [SGD] Iter 00593/03000 | Loss 0.013127 | PSNR_gt 23.90 | PSNR_gt_sm 24.29
# [SGD] Iter 00594/03000 | Loss 0.013193 | PSNR_gt 23.80 | PSNR_gt_sm 24.29
# [SGD] Iter 00595/03000 | Loss 0.013281 | PSNR_gt 23.75 | PSNR_gt_sm 24.30
# [SGD] Iter 00596/03000 | Loss 0.013353 | PSNR_gt 23.64 | PSNR_gt_sm 24.30
# [SGD] Iter 00597/03000 | Loss 0.013378 | PSNR_gt 23.64 | PSNR_gt_sm 24.31
# [SGD] Iter 00598/03000 | Loss 0.013364 | PSNR_gt 23.64 | PSNR_gt_sm 24.31
# [SGD] Iter 00599/03000 | Loss 0.013258 | PSNR_gt 23.75 | PSNR_gt_sm 24.32
# [SGD] Iter 00600/03000 | Loss 0.013149 | PSNR_gt 23.86 | PSNR_gt_sm 24.32
# [SGD] Iter 00601/03000 | Loss 0.013050 | PSNR_gt 23.99 | PSNR_gt_sm 24.32
# [SGD] Iter 00602/03000 | Loss 0.013031 | PSNR_gt 23.98 | PSNR_gt_sm 24.33
# [SGD] Iter 00603/03000 | Loss 0.013036 | PSNR_gt 23.99 | PSNR_gt_sm 24.33
# [SGD] Iter 00604/03000 | Loss 0.012884 | PSNR_gt 24.14 | PSNR_gt_sm 24.34
# [SGD] Iter 00605/03000 | Loss 0.012823 | PSNR_gt 24.23 | PSNR_gt_sm 24.34
# [SGD] Iter 00606/03000 | Loss 0.012818 | PSNR_gt 24.21 | PSNR_gt_sm 24.35
# [SGD] Iter 00607/03000 | Loss 0.012815 | PSNR_gt 24.25 | PSNR_gt_sm 24.36
# [SGD] Iter 00608/03000 | Loss 0.012839 | PSNR_gt 24.21 | PSNR_gt_sm 24.36
# [SGD] Iter 00609/03000 | Loss 0.012886 | PSNR_gt 24.16 | PSNR_gt_sm 24.37
# [SGD] Iter 00610/03000 | Loss 0.012885 | PSNR_gt 24.15 | PSNR_gt_sm 24.37
# [SGD] Iter 00611/03000 | Loss 0.012992 | PSNR_gt 24.04 | PSNR_gt_sm 24.38
# [SGD] Iter 00612/03000 | Loss 0.013068 | PSNR_gt 23.95 | PSNR_gt_sm 24.38
# [SGD] Iter 00613/03000 | Loss 0.013157 | PSNR_gt 23.86 | PSNR_gt_sm 24.39
# [SGD] Iter 00614/03000 | Loss 0.013085 | PSNR_gt 23.93 | PSNR_gt_sm 24.39
# [SGD] Iter 00615/03000 | Loss 0.013168 | PSNR_gt 23.85 | PSNR_gt_sm 24.40
# [SGD] Iter 00616/03000 | Loss 0.013162 | PSNR_gt 23.85 | PSNR_gt_sm 24.40
# [SGD] Iter 00617/03000 | Loss 0.013104 | PSNR_gt 23.91 | PSNR_gt_sm 24.41
# [SGD] Iter 00618/03000 | Loss 0.013036 | PSNR_gt 23.99 | PSNR_gt_sm 24.41
# [SGD] Iter 00619/03000 | Loss 0.013045 | PSNR_gt 23.97 | PSNR_gt_sm 24.41
# [SGD] Iter 00620/03000 | Loss 0.012988 | PSNR_gt 24.04 | PSNR_gt_sm 24.42
# [SGD] Iter 00621/03000 | Loss 0.012860 | PSNR_gt 24.18 | PSNR_gt_sm 24.42
# [SGD] Iter 00622/03000 | Loss 0.012858 | PSNR_gt 24.19 | PSNR_gt_sm 24.43
# [SGD] Iter 00623/03000 | Loss 0.012801 | PSNR_gt 24.25 | PSNR_gt_sm 24.43
# [SGD] Iter 00624/03000 | Loss 0.012813 | PSNR_gt 24.24 | PSNR_gt_sm 24.44
# [SGD] Iter 00625/03000 | Loss 0.012826 | PSNR_gt 24.22 | PSNR_gt_sm 24.45
# [SGD] Iter 00626/03000 | Loss 0.012883 | PSNR_gt 24.16 | PSNR_gt_sm 24.45
# [SGD] Iter 00627/03000 | Loss 0.012870 | PSNR_gt 24.17 | PSNR_gt_sm 24.46
# [SGD] Iter 00628/03000 | Loss 0.012949 | PSNR_gt 24.08 | PSNR_gt_sm 24.46
# [SGD] Iter 00629/03000 | Loss 0.012948 | PSNR_gt 24.08 | PSNR_gt_sm 24.47
# [SGD] Iter 00630/03000 | Loss 0.013095 | PSNR_gt 23.92 | PSNR_gt_sm 24.47
# [SGD] Iter 00631/03000 | Loss 0.013085 | PSNR_gt 23.92 | PSNR_gt_sm 24.47
# [SGD] Iter 00632/03000 | Loss 0.013034 | PSNR_gt 24.00 | PSNR_gt_sm 24.48
# [SGD] Iter 00633/03000 | Loss 0.013022 | PSNR_gt 23.99 | PSNR_gt_sm 24.48
# [SGD] Iter 00634/03000 | Loss 0.013179 | PSNR_gt 23.84 | PSNR_gt_sm 24.49
# [SGD] Iter 00635/03000 | Loss 0.013019 | PSNR_gt 24.00 | PSNR_gt_sm 24.49
# [SGD] Iter 00636/03000 | Loss 0.012943 | PSNR_gt 24.09 | PSNR_gt_sm 24.50
# [SGD] Iter 00637/03000 | Loss 0.012944 | PSNR_gt 24.08 | PSNR_gt_sm 24.50
# [SGD] Iter 00638/03000 | Loss 0.012804 | PSNR_gt 24.24 | PSNR_gt_sm 24.51
# [SGD] Iter 00639/03000 | Loss 0.012882 | PSNR_gt 24.15 | PSNR_gt_sm 24.51
# [SGD] Iter 00640/03000 | Loss 0.012948 | PSNR_gt 24.09 | PSNR_gt_sm 24.52
# [SGD] Iter 00641/03000 | Loss 0.012918 | PSNR_gt 24.10 | PSNR_gt_sm 24.52
# [SGD] Iter 00642/03000 | Loss 0.013031 | PSNR_gt 23.99 | PSNR_gt_sm 24.52
# [SGD] Iter 00643/03000 | Loss 0.013059 | PSNR_gt 23.95 | PSNR_gt_sm 24.53
# [SGD] Iter 00644/03000 | Loss 0.013084 | PSNR_gt 23.93 | PSNR_gt_sm 24.53
# [SGD] Iter 00645/03000 | Loss 0.012936 | PSNR_gt 24.10 | PSNR_gt_sm 24.54
# [SGD] Iter 00646/03000 | Loss 0.012920 | PSNR_gt 24.11 | PSNR_gt_sm 24.54
# [SGD] Iter 00647/03000 | Loss 0.012909 | PSNR_gt 24.12 | PSNR_gt_sm 24.55
# ...
# [LBFGS] Iter 00340/03000 | Loss 0.012589 | PSNR_gt 24.51 | PSNR_gt_sm 24.26
# [LBFGS] Iter 00341/03000 | Loss 0.012579 | PSNR_gt 24.52 | PSNR_gt_sm 24.27
# [LBFGS] Iter 00342/03000 | Loss 0.012574 | PSNR_gt 24.52 | PSNR_gt_sm 24.28
# [LBFGS] Iter 00343/03000 | Loss 0.012572 | PSNR_gt 24.53 | PSNR_gt_sm 24.29
# [LBFGS] Iter 00344/03000 | Loss 0.012559 | PSNR_gt 24.55 | PSNR_gt_sm 24.30
# [LBFGS] Iter 00345/03000 | Loss 0.012559 | PSNR_gt 24.55 | PSNR_gt_sm 24.31
# [LBFGS] Iter 00346/03000 | Loss 0.012580 | PSNR_gt 24.52 | PSNR_gt_sm 24.32
# [LBFGS] Iter 00347/03000 | Loss 0.012563 | PSNR_gt 24.54 | PSNR_gt_sm 24.32
# [LBFGS] Iter 00348/03000 | Loss 0.012572 | PSNR_gt 24.53 | PSNR_gt_sm 24.33
# [LBFGS] Iter 00349/03000 | Loss 0.012528 | PSNR_gt 24.58 | PSNR_gt_sm 24.34
# [LBFGS] Iter 00350/03000 | Loss 0.012606 | PSNR_gt 24.48 | PSNR_gt_sm 24.35
# [LBFGS] Iter 00351/03000 | Loss 0.012572 | PSNR_gt 24.53 | PSNR_gt_sm 24.36
# [LBFGS] Iter 00352/03000 | Loss 0.012560 | PSNR_gt 24.55 | PSNR_gt_sm 24.37
# [LBFGS] Iter 00353/03000 | Loss 0.012538 | PSNR_gt 24.56 | PSNR_gt_sm 24.38
# [LBFGS] Iter 00354/03000 | Loss 0.012523 | PSNR_gt 24.59 | PSNR_gt_sm 24.39
# [LBFGS] Iter 00355/03000 | Loss 0.012515 | PSNR_gt 24.60 | PSNR_gt_sm 24.40
# [LBFGS] Iter 00356/03000 | Loss 0.012472 | PSNR_gt 24.66 | PSNR_gt_sm 24.41
# [LBFGS] Iter 00357/03000 | Loss 0.012473 | PSNR_gt 24.64 | PSNR_gt_sm 24.42
# [LBFGS] Iter 00358/03000 | Loss 0.012524 | PSNR_gt 24.58 | PSNR_gt_sm 24.43
# [LBFGS] Iter 00359/03000 | Loss 0.012473 | PSNR_gt 24.65 | PSNR_gt_sm 24.44
# [LBFGS] Iter 00360/03000 | Loss 0.012488 | PSNR_gt 24.64 | PSNR_gt_sm 24.45
# [LBFGS] Iter 00361/03000 | Loss 0.012490 | PSNR_gt 24.64 | PSNR_gt_sm 24.46
# [LBFGS] Iter 00362/03000 | Loss 0.012492 | PSNR_gt 24.63 | PSNR_gt_sm 24.47
# [LBFGS] Iter 00363/03000 | Loss 0.012439 | PSNR_gt 24.70 | PSNR_gt_sm 24.48
# [LBFGS] Iter 00364/03000 | Loss 0.012509 | PSNR_gt 24.62 | PSNR_gt_sm 24.49
# [LBFGS] Iter 00365/03000 | Loss 0.012486 | PSNR_gt 24.63 | PSNR_gt_sm 24.49
# [LBFGS] Iter 00366/03000 | Loss 0.012454 | PSNR_gt 24.67 | PSNR_gt_sm 24.50
# [LBFGS] Iter 00367/03000 | Loss 0.012422 | PSNR_gt 24.70 | PSNR_gt_sm 24.51
# [LBFGS] Iter 00368/03000 | Loss 0.012498 | PSNR_gt 24.62 | PSNR_gt_sm 24.52
# [LBFGS] Iter 00369/03000 | Loss 0.012498 | PSNR_gt 24.62 | PSNR_gt_sm 24.53
# [LBFGS] Iter 00370/03000 | Loss 0.012465 | PSNR_gt 24.66 | PSNR_gt_sm 24.54
# [LBFGS] Iter 00371/03000 | Loss 0.012437 | PSNR_gt 24.70 | PSNR_gt_sm 24.55
# [LBFGS] Iter 00372/03000 | Loss 0.012397 | PSNR_gt 24.76 | PSNR_gt_sm 24.56
# [LBFGS] Iter 00373/03000 | Loss 0.012377 | PSNR_gt 24.78 | PSNR_gt_sm 24.57
# [LBFGS] Iter 00374/03000 | Loss 0.012404 | PSNR_gt 24.73 | PSNR_gt_sm 24.58
# [LBFGS] Iter 00375/03000 | Loss 0.012351 | PSNR_gt 24.81 | PSNR_gt_sm 24.59
# [LBFGS] Iter 00376/03000 | Loss 0.012395 | PSNR_gt 24.75 | PSNR_gt_sm 24.60
# [LBFGS] Iter 00377/03000 | Loss 0.012368 | PSNR_gt 24.78 | PSNR_gt_sm 24.60
# [LBFGS] Iter 00378/03000 | Loss 0.012372 | PSNR_gt 24.78 | PSNR_gt_sm 24.61
# [LBFGS] Iter 00379/03000 | Loss 0.012330 | PSNR_gt 24.83 | PSNR_gt_sm 24.62
# [LBFGS] Iter 00380/03000 | Loss 0.012352 | PSNR_gt 24.80 | PSNR_gt_sm 24.63
# [LBFGS] Iter 00381/03000 | Loss 0.012367 | PSNR_gt 24.78 | PSNR_gt_sm 24.64
# [LBFGS] Iter 00382/03000 | Loss 0.012346 | PSNR_gt 24.81 | PSNR_gt_sm 24.65
# [LBFGS] Iter 00383/03000 | Loss 0.012317 | PSNR_gt 24.85 | PSNR_gt_sm 24.66
# [LBFGS] Iter 00384/03000 | Loss 0.012331 | PSNR_gt 24.84 | PSNR_gt_sm 24.67
# [LBFGS] Iter 00385/03000 | Loss 0.012355 | PSNR_gt 24.79 | PSNR_gt_sm 24.68
# [LBFGS] Iter 00386/03000 | Loss 0.012299 | PSNR_gt 24.88 | PSNR_gt_sm 24.69
# [LBFGS] Iter 00387/03000 | Loss 0.012374 | PSNR_gt 24.78 | PSNR_gt_sm 24.70
# [LBFGS] Iter 00388/03000 | Loss 0.012288 | PSNR_gt 24.89 | PSNR_gt_sm 24.71
# [LBFGS] Iter 00389/03000 | Loss 0.012300 | PSNR_gt 24.88 | PSNR_gt_sm 24.72
# [LBFGS] Iter 00390/03000 | Loss 0.012286 | PSNR_gt 24.90 | PSNR_gt_sm 24.73
# [LBFGS] Iter 00391/03000 | Loss 0.012291 | PSNR_gt 24.89 | PSNR_gt_sm 24.74
# [LBFGS] Iter 00392/03000 | Loss 0.012282 | PSNR_gt 24.89 | PSNR_gt_sm 24.74
# [LBFGS] Iter 00393/03000 | Loss 0.012295 | PSNR_gt 24.87 | PSNR_gt_sm 24.75
# [LBFGS] Iter 00394/03000 | Loss 0.012271 | PSNR_gt 24.92 | PSNR_gt_sm 24.76
# [LBFGS] Iter 00395/03000 | Loss 0.012275 | PSNR_gt 24.89 | PSNR_gt_sm 24.77
# [LBFGS] Iter 00396/03000 | Loss 0.012331 | PSNR_gt 24.82 | PSNR_gt_sm 24.78
# [LBFGS] Iter 00397/03000 | Loss 0.012320 | PSNR_gt 24.85 | PSNR_gt_sm 24.79
# [LBFGS] Iter 00398/03000 | Loss 0.012330 | PSNR_gt 24.83 | PSNR_gt_sm 24.80
# [LBFGS] Iter 00399/03000 | Loss 0.012303 | PSNR_gt 24.88 | PSNR_gt_sm 24.81
# [LBFGS] Iter 00400/03000 | Loss 0.012295 | PSNR_gt 24.87 | PSNR_gt_sm 24.82
# [LBFGS] Iter 00401/03000 | Loss 0.012269 | PSNR_gt 24.92 | PSNR_gt_sm 24.83
# [LBFGS] Iter 00402/03000 | Loss 0.012265 | PSNR_gt 24.92 | PSNR_gt_sm 24.83
# [LBFGS] Iter 00403/03000 | Loss 0.012251 | PSNR_gt 24.93 | PSNR_gt_sm 24.84
# [LBFGS] Iter 00404/03000 | Loss 0.012289 | PSNR_gt 24.89 | PSNR_gt_sm 24.85
# [LBFGS] Iter 00405/03000 | Loss 0.012231 | PSNR_gt 24.96 | PSNR_gt_sm 24.86
# [LBFGS] Iter 00406/03000 | Loss 0.012217 | PSNR_gt 24.99 | PSNR_gt_sm 24.87
# [LBFGS] Iter 00407/03000 | Loss 0.012235 | PSNR_gt 24.97 | PSNR_gt_sm 24.88
# [LBFGS] Iter 00408/03000 | Loss 0.012257 | PSNR_gt 24.93 | PSNR_gt_sm 24.89
# [LBFGS] Iter 00409/03000 | Loss 0.012259 | PSNR_gt 24.93 | PSNR_gt_sm 24.90
# [LBFGS] Iter 00410/03000 | Loss 0.012239 | PSNR_gt 24.95 | PSNR_gt_sm 24.90
# [LBFGS] Iter 00411/03000 | Loss 0.012275 | PSNR_gt 24.91 | PSNR_gt_sm 24.91
# [LBFGS] Iter 00412/03000 | Loss 0.012208 | PSNR_gt 25.00 | PSNR_gt_sm 24.92
# [LBFGS] Iter 00413/03000 | Loss 0.012187 | PSNR_gt 25.02 | PSNR_gt_sm 24.93
# [LBFGS] Iter 00414/03000 | Loss 0.012216 | PSNR_gt 24.98 | PSNR_gt_sm 24.94
# [LBFGS] Iter 00415/03000 | Loss 0.012200 | PSNR_gt 25.01 | PSNR_gt_sm 24.95
# [LBFGS] Iter 00416/03000 | Loss 0.012155 | PSNR_gt 25.07 | PSNR_gt_sm 24.96
# [LBFGS] Iter 00417/03000 | Loss 0.012169 | PSNR_gt 25.04 | PSNR_gt_sm 24.96
# [LBFGS] Iter 00418/03000 | Loss 0.012140 | PSNR_gt 25.09 | PSNR_gt_sm 24.97
# [LBFGS] Iter 00419/03000 | Loss 0.012179 | PSNR_gt 25.02 | PSNR_gt_sm 24.98
# [LBFGS] Iter 00420/03000 | Loss 0.012153 | PSNR_gt 25.06 | PSNR_gt_sm 24.99
# [LBFGS] Iter 00421/03000 | Loss 0.012141 | PSNR_gt 25.07 | PSNR_gt_sm 25.00
# [LBFGS] Iter 00422/03000 | Loss 0.012183 | PSNR_gt 25.03 | PSNR_gt_sm 25.01
# [LBFGS] Iter 00423/03000 | Loss 0.012169 | PSNR_gt 25.06 | PSNR_gt_sm 25.01
# [LBFGS] Iter 00424/03000 | Loss 0.012154 | PSNR_gt 25.07 | PSNR_gt_sm 25.02
# [LBFGS] Iter 00425/03000 | Loss 0.012153 | PSNR_gt 25.07 | PSNR_gt_sm 25.03
# [LBFGS] Iter 00426/03000 | Loss 0.012108 | PSNR_gt 25.15 | PSNR_gt_sm 25.04
# [LBFGS] Iter 00427/03000 | Loss 0.012159 | PSNR_gt 25.07 | PSNR_gt_sm 25.05
# [LBFGS] Iter 00428/03000 | Loss 0.012125 | PSNR_gt 25.11 | PSNR_gt_sm 25.06
# [LBFGS] Iter 00429/03000 | Loss 0.012126 | PSNR_gt 25.11 | PSNR_gt_sm 25.06
# [LBFGS] Iter 00430/03000 | Loss 0.012074 | PSNR_gt 25.19 | PSNR_gt_sm 25.07
# [LBFGS] Iter 00431/03000 | Loss 0.012114 | PSNR_gt 25.12 | PSNR_gt_sm 25.08
# [LBFGS] Iter 00432/03000 | Loss 0.012126 | PSNR_gt 25.10 | PSNR_gt_sm 25.09
# [LBFGS] Iter 00433/03000 | Loss 0.012081 | PSNR_gt 25.18 | PSNR_gt_sm 25.10
# [LBFGS] Iter 00434/03000 | Loss 0.012090 | PSNR_gt 25.16 | PSNR_gt_sm 25.11
# [LBFGS] Iter 00435/03000 | Loss 0.012134 | PSNR_gt 25.10 | PSNR_gt_sm 25.11
# [LBFGS] Iter 00436/03000 | Loss 0.012107 | PSNR_gt 25.13 | PSNR_gt_sm 25.12
# [LBFGS] Iter 00437/03000 | Loss 0.012127 | PSNR_gt 25.10 | PSNR_gt_sm 25.13
# [LBFGS] Iter 00438/03000 | Loss 0.012163 | PSNR_gt 25.05 | PSNR_gt_sm 25.14
# [LBFGS] Iter 00439/03000 | Loss 0.012125 | PSNR_gt 25.11 | PSNR_gt_sm 25.15
# [LBFGS] Iter 00440/03000 | Loss 0.012073 | PSNR_gt 25.18 | PSNR_gt_sm 25.15
# [LBFGS] Iter 00441/03000 | Loss 0.012109 | PSNR_gt 25.13 | PSNR_gt_sm 25.16
# [LBFGS] Iter 00442/03000 | Loss 0.012056 | PSNR_gt 25.20 | PSNR_gt_sm 25.17
# [LBFGS] Iter 00443/03000 | Loss 0.012072 | PSNR_gt 25.18 | PSNR_gt_sm 25.18
# [LBFGS] Iter 00444/03000 | Loss 0.012078 | PSNR_gt 25.17 | PSNR_gt_sm 25.19
# [LBFGS] Iter 00445/03000 | Loss 0.012100 | PSNR_gt 25.15 | PSNR_gt_sm 25.19
# [LBFGS] Iter 00446/03000 | Loss 0.012030 | PSNR_gt 25.24 | PSNR_gt_sm 25.20
# [LBFGS] Iter 00447/03000 | Loss 0.012043 | PSNR_gt 25.22 | PSNR_gt_sm 25.21
# [LBFGS] Iter 00448/03000 | Loss 0.012090 | PSNR_gt 25.16 | PSNR_gt_sm 25.22
# [LBFGS] Iter 00449/03000 | Loss 0.012051 | PSNR_gt 25.21 | PSNR_gt_sm 25.23
# [LBFGS] Iter 00450/03000 | Loss 0.012049 | PSNR_gt 25.21 | PSNR_gt_sm 25.23
# [LBFGS] Iter 00451/03000 | Loss 0.012060 | PSNR_gt 25.21 | PSNR_gt_sm 25.24
# [LBFGS] Iter 00452/03000 | Loss 0.012073 | PSNR_gt 25.19 | PSNR_gt_sm 25.25
# [LBFGS] Iter 00453/03000 | Loss 0.012112 | PSNR_gt 25.12 | PSNR_gt_sm 25.26
# [LBFGS] Iter 00454/03000 | Loss 0.012178 | PSNR_gt 25.03 | PSNR_gt_sm 25.26
# [LBFGS] Iter 00455/03000 | Loss 0.012124 | PSNR_gt 25.10 | PSNR_gt_sm 25.27
# [LBFGS] Iter 00456/03000 | Loss 0.012147 | PSNR_gt 25.08 | PSNR_gt_sm 25.28
# [LBFGS] Iter 00457/03000 | Loss 0.012101 | PSNR_gt 25.13 | PSNR_gt_sm 25.29
# [LBFGS] Iter 00458/03000 | Loss 0.012127 | PSNR_gt 25.10 | PSNR_gt_sm 25.29
# [LBFGS] Iter 00459/03000 | Loss 0.012025 | PSNR_gt 25.26 | PSNR_gt_sm 25.30
# [LBFGS] Iter 00460/03000 | Loss 0.011953 | PSNR_gt 25.35 | PSNR_gt_sm 25.31
# [LBFGS] Iter 00461/03000 | Loss 0.011980 | PSNR_gt 25.32 | PSNR_gt_sm 25.32
# [LBFGS] Iter 00462/03000 | Loss 0.011994 | PSNR_gt 25.30 | PSNR_gt_sm 25.32
# [LBFGS] Iter 00463/03000 | Loss 0.011954 | PSNR_gt 25.36 | PSNR_gt_sm 25.33
# [LBFGS] Iter 00464/03000 | Loss 0.011905 | PSNR_gt 25.42 | PSNR_gt_sm 25.34
# [LBFGS] Iter 00465/03000 | Loss 0.011969 | PSNR_gt 25.34 | PSNR_gt_sm 25.35
# [LBFGS] Iter 00466/03000 | Loss 0.011950 | PSNR_gt 25.37 | PSNR_gt_sm 25.36
# [LBFGS] Iter 00467/03000 | Loss 0.012009 | PSNR_gt 25.26 | PSNR_gt_sm 25.36
# [LBFGS] Iter 00468/03000 | Loss 0.011913 | PSNR_gt 25.42 | PSNR_gt_sm 25.37
# [LBFGS] Iter 00469/03000 | Loss 0.011952 | PSNR_gt 25.35 | PSNR_gt_sm 25.38
# [LBFGS] Iter 00470/03000 | Loss 0.011917 | PSNR_gt 25.41 | PSNR_gt_sm 25.39
# [LBFGS] Iter 00471/03000 | Loss 0.011914 | PSNR_gt 25.42 | PSNR_gt_sm 25.40
# [LBFGS] Iter 00472/03000 | Loss 0.011876 | PSNR_gt 25.47 | PSNR_gt_sm 25.40
# [LBFGS] Iter 00473/03000 | Loss 0.011923 | PSNR_gt 25.41 | PSNR_gt_sm 25.41
# [LBFGS] Iter 00474/03000 | Loss 0.011933 | PSNR_gt 25.39 | PSNR_gt_sm 25.42
# [LBFGS] Iter 00475/03000 | Loss 0.011989 | PSNR_gt 25.31 | PSNR_gt_sm 25.43
# [LBFGS] Iter 00476/03000 | Loss 0.011959 | PSNR_gt 25.35 | PSNR_gt_sm 25.43
# [LBFGS] Iter 00477/03000 | Loss 0.011937 | PSNR_gt 25.38 | PSNR_gt_sm 25.44
# [LBFGS] Iter 00478/03000 | Loss 0.011895 | PSNR_gt 25.45 | PSNR_gt_sm 25.45
# [LBFGS] Iter 00479/03000 | Loss 0.011886 | PSNR_gt 25.46 | PSNR_gt_sm 25.46
# [LBFGS] Iter 00480/03000 | Loss 0.011856 | PSNR_gt 25.50 | PSNR_gt_sm 25.47
# [LBFGS] Iter 00481/03000 | Loss 0.011911 | PSNR_gt 25.42 | PSNR_gt_sm 25.47
# [LBFGS] Iter 00482/03000 | Loss 0.011865 | PSNR_gt 25.48 | PSNR_gt_sm 25.48
# [LBFGS] Iter 00483/03000 | Loss 0.011883 | PSNR_gt 25.46 | PSNR_gt_sm 25.49
# [LBFGS] Iter 00484/03000 | Loss 0.011851 | PSNR_gt 25.51 | PSNR_gt_sm 25.50
# [LBFGS] Iter 00485/03000 | Loss 0.011835 | PSNR_gt 25.53 | PSNR_gt_sm 25.50
# [LBFGS] Iter 00486/03000 | Loss 0.011863 | PSNR_gt 25.50 | PSNR_gt_sm 25.51
# [LBFGS] Iter 00487/03000 | Loss 0.011821 | PSNR_gt 25.56 | PSNR_gt_sm 25.52
# [LBFGS] Iter 00488/03000 | Loss 0.011841 | PSNR_gt 25.51 | PSNR_gt_sm 25.53
# [LBFGS] Iter 00489/03000 | Loss 0.011842 | PSNR_gt 25.54 | PSNR_gt_sm 25.54
# [LBFGS] Iter 00490/03000 | Loss 0.011823 | PSNR_gt 25.55 | PSNR_gt_sm 25.54
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# /tmp/ipython-input-1826159336.py in <cell line: 0>()
#     159     random.seed(2025)
#     160     lr_for_optimizer = OPTIMIZER_LRS.get(OPTIMIZER_name, LR) # Get LR from dict, fallback to global LR
# --> 161     results[OPTIMIZER_name] = run_optimizer(OPTIMIZER_name, lr_for_optimizer)
#     162
#     163
#
# /tmp/ipython-input-1826159336.py in run_optimizer(OPTIMIZER_name, current_LR)
#     135
#     136     p = get_params(OPT_OVER, net, net_input)
# --> 137     optimize(OPTIMIZER_name, p, closure, current_LR, num_iter) # Use current_LR here
#     138
#     139     return {
#
# /tmp/ipython-input-4022371882.py in optimize(optimizer_type, parameters, closure, LR, num_iter)
#       7             return closure()
#       8         optimizer = torch.optim.LBFGS(parameters, max_iter=num_iter, lr=LR, tolerance_grad=-1, tolerance_change=-1)
# ----> 9         optimizer.step(closure2)
#      10
#      11     else:
#
# /usr/local/lib/python3.12/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#     515                             )
#     516
# --> 517                 out = func(*args, **kwargs)
#     518                 self._optimizer_step_code()
#     519
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     118     def decorate_context(*args, **kwargs):
#     119         with ctx_factory():
# --> 120             return func(*args, **kwargs)
#     121
#     122     return decorate_context
#
# /usr/local/lib/python3.12/dist-packages/torch/optim/lbfgs.py in step(self, closure)
#     455                     # no use to re-evaluate that function here
#     456                     with torch.enable_grad():
# --> 457                         loss = closure()
#     458                     loss = float(loss)
#     459                     flat_grad = self._gather_flat_grad()
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     118     def decorate_context(*args, **kwargs):
#     119         with ctx_factory():
# --> 120             return func(*args, **kwargs)
#     121
#     122     return decorate_context
#
# /tmp/ipython-input-4022371882.py in closure2()
#       5         def closure2():
#       6             optimizer.zero_grad()
# ----> 7             return closure()
#       8         optimizer = torch.optim.LBFGS(parameters, max_iter=num_iter, lr=LR, tolerance_grad=-1, tolerance_change=-1)
#       9         optimizer.step(closure2)
#
# /tmp/ipython-input-1826159336.py in closure()
#      75
#      76         total_loss = mse(out, img_noisy_torch)
# ---> 77         total_loss.backward()
#      78         loss_values.append(total_loss.item())
#      79
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     623                 inputs=inputs,
#     624             )
# --> 625         torch.autograd.backward(
#     626             self, gradient, retain_graph, create_graph, inputs=inputs
#     627         )
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     352     # some Python versions print out the first line of a multi-line function
#     353     # calls in the traceback and some print out the last line
# --> 354     _engine_run_backward(
#     355         tensors,
#     356         grad_tensors_,
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     839         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     840     try:
# --> 841         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     842             t_outputs, *args, **kwargs
#     843         )  # Calls into the C++ engine to run the backward pass
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 128.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 12.12 MiB is free. Process 3225 has 14.73 GiB memory in use. Of the allocated memory 14.00 GiB is allocated by PyTorch, and 615.10 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
def plot_fre_vs_adam_at_same_loss(results, other_optimizers, frequency_bias_func, loss_key='loss', tol=1e-3):
    """
    绘制 Adam 与其他优化器在与 Adam 相同 loss 对应图像的频域误差曲线。

    Args:
        results: dict, 每个 optimizer 的结果，如 results['adam']['finalresult'] 和 results['adam']['loss']
        other_optimizers: list of str, 其他 optimizer 名称
        frequency_bias_func: function, 输入 torch.Tensor 返回标量 float
        loss_key: str, 保存 loss 的键名
        tol: float, 匹配 loss 的容忍度
    """
    adam_loss = np.array(results['adam'][loss_key])
    adam_imgs = results['adam']['finalresult']

    plt.figure(figsize=(35, 28))

    for name in other_optimizers:
        optimizer_loss = np.array(results[name][loss_key])
        optimizer_imgs = results[name]['finalresult']

        error = []
        for i, l_adam in enumerate(adam_loss):
            # 找到满足容忍度的索引
            candidates = np.where(np.abs(optimizer_loss - l_adam)/np.minimum(optimizer_loss,l_adam) < tol)[0]

            if len(candidates) == 0:
                # 如果没有符合 tol 的 loss，则跳过
                continue
            else:
                idx = candidates[0]  # 可以选第一个，也可以用平均或其他策略

            x1 = adam_imgs[i].detach()
            x2 = optimizer_imgs[idx].detach()

            ferror = frequency_bias_func(x1, x2)
            error.append(ferror)

        plt.plot(range(len(error)), error, marker='o', linestyle='-', label=f"Adam vs {name}")

    plt.xlabel("Adam Loss Index")
    plt.ylabel("Frequency-domain Error")
    plt.title(f"Frequency Error at Same Loss as Adam (tol={tol})")
    plt.legend()
    plt.grid(True)
    plt.show()

# other_optimizers = ['SGD', 'LBFGS']  #  ['SGD', 'LBFGS', 'ASGD', 'AdamW', 'RAdam'] #
# plot_fre_vs_adam_at_same_loss(results, other_optimizers, frequency_bias_func=frequency_bias_diff, tol=0.001)

# %%
markers = {
    'adam': 'o',
    'SGD': 's',
    'AdamW': '*',
    'RAdam': 'x',
    'ASGD': '^',
    'LBFGS': 'P'
}
plt.figure(figsize=(28, 21))
for opt_name, data in results.items():
    plt.plot(data['loss'], data['psnr'], label=f'{opt_name} (LR={OPTIMIZER_LRS.get(opt_name, LR)})', marker=markers[opt_name], linestyle=' ')
plt.xlabel('Loss')
plt.ylabel('PSNR (GT)')
plt.title('PSNR vs. Loss Curve for Different Optimizers')
plt.legend()
plt.grid(True)
plt.show()

# %%
def plot_psnr_diff_at_same_loss(results, baseline='adam', tol=1e-3):
    """
    Plot PSNR differences at same loss between baseline and other optimizers.

    Args:
        results: dict, each optimizer has keys: ['loss'], ['psnr']
        baseline: str, baseline optimizer name
        tol: float, tolerance for matching losses
    """

    base_loss = np.array(results[baseline]['loss'])
    base_psnr = np.array(results[baseline]['psnr'])

    plt.figure(figsize=(18, 12))

    for opt_name, data in results.items():
        if opt_name == baseline:
            continue

        opt_loss = np.array(data['loss'])
        opt_psnr = np.array(data['psnr'])

        diff_curve = []
        valid_idx = []

        for i, l_base in enumerate(base_loss):

            # 找所有满足 |opt_loss - l_base| < tol 的 index
            candidates = np.where(np.abs(opt_loss - l_base)/np.minimum(opt_loss,l_base) < tol)[0]

            if len(candidates) == 0:
                continue  # 该 base loss 没有匹配点

            # 按照最接近的 loss 选
            idx = candidates[np.argmin(np.abs(opt_loss[candidates] - l_base))]

            # print(opt_loss[idx],l_base)
            # print(idx, i)

            psnr_diff = base_psnr[i] - opt_psnr[idx]

            diff_curve.append(psnr_diff)
            valid_idx.append(i)

        if len(diff_curve) == 0:
            print(f"[Warning] No matched loss points for {opt_name}")
            continue

        plt.plot(valid_idx, diff_curve, label=f"{baseline} - {opt_name}", marker='o')
        print(len(valid_idx))
        # base_loss = np.array(results['SGD']['loss'])
        # print(np.min(base_loss),np.average(base_loss))
        # print(np.sum(opt_loss[valid_idx] <= np.average(opt_loss[valid_idx])))


    plt.xlabel("Baseline Loss Index")
    plt.ylabel("PSNR Difference (Baseline - Optimizer)")
    plt.title(f"PSNR Differences at Same Loss (tol={tol})")
    plt.legend()
    plt.grid(True)
    plt.show()

plot_psnr_diff_at_same_loss(results, baseline='adam', tol=0.001)

# %%
def frequency_bias_diff_2norm(x1,x2):
    Xf1 = torch.fft.fft2(x1, norm='ortho')
    Xf2 = torch.fft.fft2(x2, norm='ortho')
    Xf_mag1 = torch.abs(Xf1)
    Xf_mag2 = torch.abs(Xf2)
    log_fx1 = Xf_mag1#torch.log1p(Xf_mag1)
    log_fx2 = Xf_mag2#torch.log1p(Xf_mag2)
    diff = log_fx1 - log_fx2
    result = torch.norm(diff, p=2).item()/torch.norm(log_fx1, p=2).item()
    # num_up = torch.norm(diff, p=2).item()
    # num_down = np.minimum(torch.norm(log_fx1, p=2).item(),torch.norm(log_fx2, p=2).item())
    # result = num_up / num_down
    # print(result)
    return result
def plot_frequency_and_psnr_diff_at_same_loss(
        results,
        other_optimizers,
        frequency_bias_func,
        loss_key='loss',
        tol=1e-3):
    """
    同时绘制 Adam 与其他优化器在相同 loss 下的：
        (1) 频域误差 difference curve
        (2) PSNR difference curve

    Args:
        results: dict，包含每个优化器的 loss 和 finalresult
        other_optimizers: list[str]，其他优化器名称
        frequency_bias_func: 输入(x1, x2) → 标量
        loss_key: str
        tol: float，相同 loss 判定 tol（相对误差）
    """
    adam_loss = np.array(results['adam'][loss_key])
    adam_imgs = results['adam']['finalresult']

    plt.figure(figsize=(40, 30))

    # 两个 subplot：频域误差 & PSNR 差
    ax1 = plt.subplot(2, 1, 1)
    ax2 = plt.subplot(2, 1, 2)

    for name in other_optimizers:
        optimizer_loss = np.array(results[name][loss_key])
        optimizer_imgs = results[name]['finalresult']

        fre_error = []
        psnr_diff = []  # PSNR(adam) - PSNR(opt)

        for i, l_adam in enumerate(adam_loss):

            # 相对误差匹配：|l1 - l2| < tol * min(l1, l2)
            denom = max(min(l_adam, np.min(optimizer_loss)), 1e-12)
            valid_idx = np.where(np.abs(optimizer_loss - l_adam) / denom < tol)[0]

            if len(valid_idx) == 0:
                fre_error.append(np.nan)
                psnr_diff.append(np.nan)
                continue

            idx = valid_idx[np.argmin(np.abs(optimizer_loss[valid_idx] - l_adam))]

            x1 = adam_imgs[i].detach().cpu()
            x2 = optimizer_imgs[idx].detach().cpu()
            # print(idx, i)
            if False: #i % 100 == 0:
                print(adam_loss[i], optimizer_loss[idx])
                x1_np = x1.squeeze(0).cpu().numpy()
                x2_np = x2.squeeze(0).cpu().numpy()
                plot_image_grid([x1_np, x2_np, (x1_np-x2_np)], 4, 6)
                print('PSNR:', results['adam']['psnr'][i], results[name]['psnr'][idx])
                print('norm error:', torch.norm(x1-x2, p=2).item()/torch.norm(x1, p=2).item())
                Xf1 = torch.fft.fft2(x1, norm='ortho')
                Xf2 = torch.fft.fft2(x2, norm='ortho')
                Xf_mag1 = torch.abs(Xf1)
                Xf_mag2 = torch.abs(Xf2)
                print('norm |Fx| error:', torch.norm(Xf_mag1-Xf_mag2, p=2).item()/torch.norm(Xf_mag1, p=2).item())
                plot_image_grid([Xf_mag1.squeeze(0).cpu().numpy()*255, Xf_mag2.squeeze(0).cpu().numpy()*255,(Xf_mag1.squeeze(0).cpu().numpy()-Xf_mag2.squeeze(0).cpu().numpy())*255], 4, 6)


            # 频域误差
            ferror = frequency_bias_func(x1, x2)
            fre_error.append(ferror)

            # PSNR 差
            p_adam = results['adam']['psnr'][i]
            p_opt  = results[name]['psnr'][idx]
            psnr_diff.append(p_adam - p_opt)

        # === 绘制频域误差 ===
        ax1.plot(fre_error, marker='o', linestyle='-', label=f"Adam vs {name}")

        # === 绘制 PSNR 差 ===
        ax2.plot(psnr_diff, marker='s', linestyle='--', label=f"Adam vs {name}")

    ax1.set_title("Frequency-domain Error at Same Loss")
    ax1.set_ylabel("Frequency Error")
    ax1.grid(True)
    ax1.legend()

    ax2.set_title("PSNR Difference at Same Loss (Adam - Optimizer)")
    ax2.set_xlabel("Adam Loss Index")
    ax2.set_ylabel("PSNR Difference")
    ax2.grid(True)
    ax2.legend()

    plt.tight_layout()
    plt.show()
other_optimizers =  ['SGD', 'LBFGS', 'ASGD', 'AdamW', 'RAdam'] #['SGD', 'LBFGS']

plot_frequency_and_psnr_diff_at_same_loss(
    results,
    other_optimizers,
    frequency_bias_func=frequency_bias_diff_2norm,
    tol=1e-2
)

# %%
import torchvision.transforms.functional as TF
def smooth_freq_diff(x1,x2, kernel_size=5):
    """
    Smooth the FFT magnitude (log domain) before computing metrics.
    """
    xx1 = TF.gaussian_blur(x1, kernel_size=kernel_size, sigma=1.0)
    xx2 = TF.gaussian_blur(x2, kernel_size=kernel_size, sigma=1.0)
    Xf1 = torch.fft.fft2(xx1, norm='ortho')
    Xf2 = torch.fft.fft2(xx2, norm='ortho')
    Xf_mag1 = torch.abs(Xf1)
    Xf_mag2 = torch.abs(Xf2)
    log_fx1 = Xf_mag1 #torch.log1p(Xf_mag1)
    log_fx2 = Xf_mag2 #torch.log1p(Xf_mag2)
    diff = log_fx1 - log_fx2
    num_up = torch.norm(diff, p=2).item()
    num_down = np.minimum(torch.norm(log_fx1, p=2).item(),torch.norm(log_fx2, p=2).item())
    result = num_up / num_down
    return result
other_optimizers =  ['SGD', 'LBFGS', 'ASGD', 'AdamW', 'RAdam'] #['SGD', 'LBFGS']
plot_frequency_and_psnr_diff_at_same_loss(
    results,
    other_optimizers,
    frequency_bias_func=smooth_freq_diff,
    tol=1e-2
)

# %%
def plot_ssim_vs_loss_all_optimizers(results, gt):
    """
    对所有 optimizer 的输出计算 SSIM 并画出 SSIM vs Loss 曲线。

    Args:
        results: dict, 每个 optimizer 的结果，如 results['adam']['finalresult'] 和 results['adam']['loss']
        gt: numpy array, ground truth 图像，shape (C,H,W)
    """
    plt.figure(figsize=(40,30))

    for opt_name, data in results.items():
        losses = data['loss']
        outputs = data['finalresult']

        ssim_vals = []
        for out in outputs:
            img_out = out.detach().cpu().numpy()[0]
            img_out = img_out.transpose(1,2,0)
            ssim_val = compare_ssim(gt.transpose(1,2,0), img_out, channel_axis=-1, data_range=gt.max() - gt.min())

            ssim_vals.append(ssim_val)

        plt.plot(losses, ssim_vals, marker='o', linestyle='-', label=opt_name)

    plt.xlabel("Loss")
    plt.ylabel("SSIM")
    plt.title("SSIM vs Loss for All Optimizers")
    plt.legend()
    plt.grid(True)
    plt.show()

# 假设 img_np 是 GT 图像
plot_ssim_vs_loss_all_optimizers(results, img_np)
